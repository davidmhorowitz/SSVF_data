# %%
import pandas as pd

# %%
df_16_17 = pd.read_excel("FINAL Data - FY 2016-2017_Excluding PII.xlsx")
df_18_20 = pd.read_excel("FINAL Data - FY 2018-2020_Excluding PII.xlsx")
df_21_22 = pd.read_excel("SSVF Annual National Report Data Oct 21 - Sep 22_Excluding PII.xlsx")
pd.set_option('display.max_columns', None)

# %%
#Imported the three main tables of results.

# %%
list_of_tables = [df_16_17, df_18_20, df_21_22]
#printing all columns
for table in list_of_tables:
    print(table.columns)
    print(len(table.columns))
    print("========")
# Out:
# Index(['ResponseID', 'ResponseSet', 'IPAddress', 'StartDate', 'EndDate',
#        'RecipientLastName', 'RecipientFirstName', 'RecipientEmail',
#        'ExternalDataReference', 'Finished', 'Status', 'va Cell Phone',
#        'Response ID', 'Timestamp MM/dd/yyyy', 'Custom Variable 1',
#        'Custom Variable 2', 'Custom Variable 3', 'Custom Variable 4',
#        'Respondent Email', 'Region',
#        'How many people are in the veterans household including the veteran',
#        'Veterans First Name if first name is not provided  please type',
#        'Veterans Email Address yourname.com',
#        'Cell Phone XXX-XXX-XXXX 1-999-999-9999', 'UserAgent', 'Q_URL', 'Q35',
#        'QIS', 'QIVA', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q7', 'F37',
#        'Q8 into', 'Q8.1-1a', 'Q8.1-1b', 'Q8.1-1c_1', 'Q8.2-2a', 'Q8.2-2b',
#        'Q8.2-2c_1', 'Q8.3-a_1', 'Q8.3-a_2', 'Q8.3-a_3', 'Q8.3-a_4', 'Q8.3-a_5',
#        'Q8.3-a_6', 'Q8.3-a_7', 'Q8.3-a_8', 'Q8.3-b_1', 'Q8.3-b_2', 'Q8.3-b_3',
#        'Q8.3-b_4', 'Q8.3-b_5', 'Q8.3-b_6', 'Q8.3-b_7', 'Q8.3-b_8', 'Q8.3-c_1',
#        'Q8.3-c_2', 'Q8.3-c_3', 'Q8.3-c_4', 'Q8.3-c_5', 'Q8.3-c_6', 'Q8.3-c_7',
#        'Q8.3-c_8', 'Q8.4-a_1', 'Q8.4-a_2', 'Q8.4-a_3', 'Q8.4-a_4', 'Q8.4-a_5',
#        'Q8.4-a_6', 'Q8.4-a_6_TEXT', 'Q8.4-b_1', 'Q8.4-b_2', 'Q8.4-b_3',
#        'Q8.4-b_4', 'Q8.4-b_5', 'Q8.4-b_6', 'Q8.4-b_6_TEXT', 'Q8.4-c_1',
#        'Q8.4-c_2', 'Q8.4-c_3', 'Q8.4-c_4', 'Q8.4-c_5', 'Q8.4-c_6',
#        'Q8.4-c_6_TEXT', 'Q15', 'Q16', 'Q17', 'Q18', 'Negative', 'date range'],
#       dtype='object')
# 95
# ========
# Index(['ResponseID', 'PIN', 'Timestamp', 'GRANT_ID', 'LEGAL_NAME', 'FNAME',
#        'PHONE', 'REMAIL', 'QA', 'QB', 'QC', 'Q1', 'Q2', 'Q2A', 'Q3_1_A',
#        'Q3_1_B', 'Q3_1_C', 'Q3_2_A', 'Q3_2_B', 'Q3_2_C', 'Q3_3_1_A',
#        'Q3_3_2_A', 'Q3_3_3_A', 'Q3_3_4_A', 'Q3_3_5_A', 'Q3_3_6_A', 'Q3_3_7_A',
#        'Q3_3_8_A', 'Q3_3_1_B', 'Q3_3_2_B', 'Q3_3_3_B', 'Q3_3_4_B', 'Q3_3_5_B',
#        'Q3_3_6_B', 'Q3_3_7_B', 'Q3_3_8_B', 'Q3_3_1_C', 'Q3_3_2_C', 'Q3_3_3_C',
#        'Q3_3_4_C', 'Q3_3_5_C', 'Q3_3_6_C', 'Q3_3_7_C', 'Q3_3_8_C', 'Q3_4_1_A',
#        'Q3_4_2_A', 'Q3_4_3_A', 'Q3_4_4_A', 'Q3_4_5_A', 'Q3_4_1_B', 'Q3_4_2_B',
#        'Q3_4_3_B', 'Q3_4_4_B', 'Q3_4_5_B', 'Q3_4_1_C', 'Q3_4_2_C', 'Q3_4_3_C',
#        'Q3_4_4_C', 'Q3_4_5_C', 'Q4', 'Q5', 'Q6', 'Q7', 'Q8', 'Q9', 'Q10',
#        'Q11', 'DateRange'],
#       dtype='object')
# 68
# ========
# Index(['UNIQUEID', 'GRANTEEID', 'MODE', 'LtCallDt', 'LtCallST', 'CallDurS',
#        'CallDurM', 'TotalTime', 'LtCallR', 'LtCaseR', 'Date', 'HOUSEHOLD',
#        'HEALTHCARE', 'HEALTHCARE2', 'Q1', 'Q1 Num', 'Q2', 'Q2A', 'Q3_1',
#        'Q3_1B', 'Q3_2', 'Q3_2B', 'Q3_3A', 'Q3_3A2', 'Q3_3B', 'Q3_3B2', 'Q3_3C',
#        'Q3_3C2', 'Q3_3D', 'Q3_3D2', 'Q3_3E', 'Q3_3E2', 'Q3_3F', 'Q3_3F2',
#        'Q3_3G', 'Q3_3G2', 'Q3_3H', 'Q3_3H2', 'Q4_A', 'Q4_A2', 'Q4_B', 'Q4_B2',
#        'Q4_C', 'Q4_C2', 'Q4_D', 'Q4_D2', 'Q4_E', 'Q4_E2', 'Q4', 'Q5', 'Q6',
#        'Q7', 'Q8', 'EXPERIENCE', 'Q9', 'Q10', 'Q11A', 'Q11', 'Q13', 'Q14',
#        'Q15', 'Q16', 'INT99', 'Q12', 'INT'],
#       dtype='object')
# 65
# ========

# %%
dlp_qs = pd.read_csv("dlp_questions_explained - Sheet1_with_data_dict.csv")
#Note that table 0 refers to the data dictionary.

# %%
dlp_qs.head(3)
# Out:
#   given_q_label  \
# 0            Q1
# 1            Q2
# 2            Q3
#
#                                                                                                                           given_q_text  \
# 0                            How would you rate the quality of the services you have\nreceived from this supportive services provider?
# 1  If another Veteran or a friend were in need of similar\nhelp, would you recommend this supportive services provider\nto him or her?
# 2                                   How satisfied are you with the services you have\nreceived from this supportive services provider?
#
#   source_type num  percent_nonnull  consistent/inconsistent  dlp_std_q  \
# 0         pdf  16              NaN                      NaN        NaN
# 1         pdf  16              NaN                      NaN        NaN
# 2         pdf  16              NaN                      NaN        NaN
#
#    dlp_id_for_std_q  dlp_qid_all_qs (index)  \
# 0               NaN                     NaN
# 1               NaN                     NaN
# 2               NaN                     NaN
#
#                                    notes
# 0  The PDF looks at Qs1 thru 4 together.
# 1                                    NaN
# 2                                    NaN

# %%
dlp_qs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   given_q_label            369 non-null    object
#  1   given_q_text             141 non-null    object
#  2   source_type              369 non-null    object
#  3   num                      305 non-null    object
#  4   percent_nonnull          228 non-null    float64
#  5   consistent/inconsistent  0 non-null      float64
#  6   dlp_std_q                0 non-null      float64
#  7   dlp_id_for_std_q         0 non-null      float64
#  8   dlp_qid_all_qs (index)   0 non-null      float64
#  9   notes                    19 non-null     object
# dtypes: float64(5), object(5)
# memory usage: 29.0+ KB

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %%
#I'm going to manually look at every question.
#I don't think there's any way around it.
#To make it easy, I'm going to bundle questions
#with the same label together.
#*starting to look into questions with multiple definitions

q_num_list = []

for q_num in dlp_qs["given_q_label"]: #for each question label
    if q_num in q_num_list:
        continue #if I already appended the question label (below), skip
    else:
        qs_per_num = ( #create a Series of questions for each q_num
            dlp_qs[
            (dlp_qs["given_q_label"] == q_num) #filter to only include the given q number
            &
            (
                (dlp_qs["source_type"] == "pdf")
            |
                (dlp_qs["source_type"] == "data dictionary")
            )
                #filter to only include pdfs and the data dictionary (since only those have question text)
        ]
        [["given_q_text", "num"]] #show the question text and their numbers
        )
        number_of_qs_per_num = len(qs_per_num)
        q_num_list.append(q_num)
        print(f'{q_num} ({number_of_qs_per_num} questions): {qs_per_num}')
        print("=======")
# Out:
# Q1 (6 questions):                                                                                                   given_q_text  \
# 0    How would you rate the quality of the services you have\nreceived from this supportive services provider?
# 7    How would you rate the quality of the services you have\nreceived from this supportive services provider?
# 13   How would you rate the quality of the services you have\nreceived from this supportive services provider?
# 20    How would you rate the quality of the services you have received from this supportive services provider?
# 30                         HOW WOULD YOU RATE THE QUALITY OF SERVICES YOU HAVE RECEIVED FROM THIS SSVF AGENCY?
# 312   How would you rate the quality of the services you have received from this supportive services provider?
#
#        num
# 0       16
# 7       17
# 13      18
# 20      20
# 30   21-22
# 312    NaN
# =======
# Q2 (4 questions):                                                                                                                             given_q_text  \
# 1    If another Veteran or a friend were in need of similar\nhelp, would you recommend this supportive services provider\nto him or her?
# 8    If another Veteran or a friend were in need of similar help,\nwould you recommend this supportive services provider to him or\nher?
# 31                                      DID THE SSVF CASE MANAGER INVOLVE YOU IN CREATING AN INDIVIDUALIZED HOUSING STABILIZATION\nPLAN?
# 313                           Did the supportive services provider involve you in creating an individualized housing stabilization plan?
#
#        num
# 1       16
# 8       17
# 31   21-22
# 313    NaN
# =======
# Q3 (2 questions):                                                                                          given_q_text  \
# 2  How satisfied are you with the services you have\nreceived from this supportive services provider?
# 9  How satisfied are you with the services you have received\nfrom this supportive services provider?
#
#   num
# 2  16
# 9  17
# =======
# Q4 (4 questions):                                                                                                                              given_q_text  \
# 3    If you needed help again and had a choice of where to\ngo at no cost to you, would you return to this supportive\nservices provider?
# 10   If you needed help again and had a choice of where to go at\nno cost to you, would you return to this supportive services\nprovider?
# 63                                            HOW MANY TIMES HAVE YOU MOVED SINCE YOU STARTED RECEIVING SERVICES FROM THIS SSVF AGENCY?\n
# 360                                                How many times have you moved since you started receiving services from this provider?
#
#        num
# 3       16
# 10      17
# 63   21-22
# 360    NaN
# =======
# Q6abc (2 questions):                                                                                                                                                                                                                                                                                                                                                                                                                                     given_q_text  \
# 4   Veterans were asked a series of questions about which supportive services they needed and\nreceived. If they received the service, they were then asked about the quality of the service.\nAfter answering questions about fifteen different specific services (inclusive of such things as\ncase management, health care and rental assistance), they were given the option to write in\nservices not mentioned that they felt they needed.
# 11  Veterans were asked a series of questions about which supportive services they needed and\nreceived. If they received the service, they were then asked about the quality of the service.\nAfter answering questions about fifteen different specific services (inclusive of such things as\ncase management, health care and rental assistance), they were given the option to write in\nservices not mentioned that they felt they needed.
#
#    num
# 4   16
# 11  17
# =======
# Q7 (6 questions):                                                                                                                                     given_q_text  \
# 5                                       Is there any other feedback\nabout the supportive services provider that\nyou wish to provide to the VA?
# 12                                      Is there any other feedback\nabout the supportive services provider that\nyou wish to provide to the VA?
# 15   How satisfied are you with the courteousness of the staff person that you dealt with most often\nwhile you were working with this provider?
# 22   How satisfied are you with the courteousness of the staff person that you dealt with most often\nwhile you were working with this provider?
# 66   HOW SATISFIED ARE YOU WITH THE COURTEOUSNESS OF THE STAFF PERSON THAT YOU DEALT WITH MOST\nOFTEN WHILE YOU WERE WORKING WITH THIS PROVIDER?
# 363   How satisfied are you with the courteousness of the staff person that you dealt with most often while you were working with this provider?
#
#        num
# 5       16
# 12      17
# 15      18
# 22      20
# 66   21-22
# 363    NaN
# =======
# Q8 (5 questions):                                                                                                                                                     given_q_text  \
# 6                                           Please indicate which supportive services you received and indicate the quality of the supportive services received.
# 16   How satisfied are you with the timeliness of communication with the staff person that you dealt\nwith most often while you were working with this provider?
# 23   How satisfied are you with the timeliness of communication with the staff person that you dealt\nwith most often while you were working with this provider?
# 67   HOW SATISFIED ARE YOU WITH THE TIMELINESS OF COMMUNICATION WITH THE STAFF PERSON THAT YOU\nDEALT WITH MOST OFTEN WHILE YOU WERE WORKING WITH THIS PROVIDER?
# 364   How satisfied are you with the timeliness of communication with the staff person that you dealt with most often while you were working with this provider?
#
#        num
# 6       16
# 16      18
# 23      20
# 67   21-22
# 364    NaN
# =======
# Q6 (4 questions):                                                                                                                          given_q_text  \
# 14   How satisfied are you with the courteousness of the staff person that you initially spoke with when\nyou contacted the provider?
# 21   How satisfied are you with the courteousness of the staff person that you initially spoke with when\nyou contacted the provider?
# 65   HOW SATISFIED ARE YOU WITH THE COURTEOUSNESS OF THE STAFF PERSON THAT YOU INITIALLY SPOKE\nWITH WHEN YOU CONTACTED THE PROVIDER?
# 362   How satisfied are you with the courteousness of the staff person that you initially spoke with when you contacted the provider?
#
#        num
# 14      18
# 21      20
# 65   21-22
# 362    NaN
# =======
# Q9 (4 questions):                                                                                        given_q_text  \
# 17   If your experiences were positive with this supportive services provider,\nplease tell us why.
# 24   If your experiences were positive with this supportive services provider,\nplease tell us why.
# 74                       Appendix A: Q9_Positive experiences with the S.S.V.F staff that helped you
# 365   If your experiences were positive with this supportive services provider, please tell us why.
#
#        num
# 17      18
# 24      20
# 74   21-22
# 365    NaN
# =======
# Q10 (4 questions):                                                                                                given_q_text  \
# 18           If your experiences were negative with this supportive services\nprovider, please tell us why.
# 25           If your experiences were negative with this supportive services\nprovider, please tell us why.
# 75   Appendix B: Q10_Negative experiences you had with the SSVF agency or S. S. V. F.\nstaff who helped you
# 366           If your experiences were negative with this supportive services provider, please tell us why.
#
#        num
# 18      18
# 25      20
# 75   21-22
# 366    NaN
# =======
# Q11 (4 questions):                                                                        given_q_text  \
# 19   Please list any additional suggestions as to how to improve the SSVF\nProgram.
# 26   Please list any additional suggestions as to how to improve the SSVF\nProgram.
# 76                       Appendix C: Q11_Suggestions to improve the S.S.V.F program
# 367   Please list any additional suggestions as to how to improve the SSVF Program.
#
#        num
# 19      18
# 26      20
# 76   21-22
# 367    NaN
# =======
# QA (2 questions):                                                                                                given_q_text  \
# 27                                                     WHAT IS THE NUMBER OF INDIVIDUALS IN YOUR HOUSEHOLD?
# 309  Number of individuals (including yourself) in household receiving support services from this provider:
#
#        num
# 27   21-22
# 309    NaN
# =======
# QB (2 questions):                                        given_q_text    num
# 28   ARE YOU ENROLLED IN THE VA HEALTH CARE SYSTEM?  21-22
# 310  Are you enrolled in the VA health care system?    NaN
# =======
# QC (2 questions):                                                                                        given_q_text  \
# 29   WERE YOU ENROLLED IN THE VA HEALTHCARE SYSTEM PRIOR TO RECEIVING SERVICES FROM THIS\nPROVIDER?
# 311  Were you enrolled in the VA health care system prior to receiving services from this provider?
#
#        num
# 29   21-22
# 311    NaN
# =======
# Q2A (2 questions):                                                          given_q_text    num
# 32   DO YOU FEEL THAT THIS HOUSING PLAN IS A GOOD FIT FOR YOUR NEEDS?  21-22
# 314  Do you feel that this housing plan is a good fit for your needs?    NaN
# =======
# Q3_1 (1 questions):                      given_q_text    num
# 33  DID YOU NEED CASE MANAGEMENT?  21-22
# =======
# Q3_1B (1 questions):                                              given_q_text    num
# 34  WHAT WAS THE QUALITY OF THE CASE MANAGEMENT RECEIVED?  21-22
# =======
# Q3_2 (1 questions):                                          given_q_text    num
# 35  DID YOU NEED ASSISTANCE IN OBTAINING VA BENEFITS?  21-22
# =======
# Q3_2B (1 questions):                                                              given_q_text  \
# 36  WHAT WAS THE QUALITY OF ASSISTANCE RECEIVED IN OBTAINING VA BENEFITS?
#
#       num
# 36  21-22
# =======
# Q3_3A (1 questions):                                                                    given_q_text  \
# 37  DID YOU NEED ASSISTANCE IN OBTAINING AND COORDINATING HEALTH CARE BENEFITS?
#
#       num
# 37  21-22
# =======
# Q3_3A2 (1 questions):                                                                                            given_q_text  \
# 38  WHAT WAS THE QUALITY OF THE ASSISTANCE RECEIVED IN OBTAINING AND COORDINATING\nHEALTHCARE BENEFITS?
#
#       num
# 38  21-22
# =======
# Q3_3B (1 questions):                                                                     given_q_text  \
# 39  DID YOU NEED ASSISTANCE IN OBTAINING AND COORDINATING DAILY LIVING BENEFITS?
#
#       num
# 39  21-22
# =======
# Q3_3B2 (1 questions):                                                                                              given_q_text  \
# 40  WHAT WAS THE QUALITY OF THE ASSISTANCE RECEIVED IN OBTAINING AND COORDINATING DAILY\nLIVING BENEFITS?
#
#       num
# 40  21-22
# =======
# Q3_3C (1 questions):                                                                                     given_q_text  \
# 41  DID YOU NEED ASSISTANCE IN OBTAINING AND COORDINATING PERSONAL FINANCIAL PLANNING\nBENEFITS?
#
#       num
# 41  21-22
# =======
# Q3_3C2 (1 questions):                                                                                                            given_q_text  \
# 42  WHAT WAS THE QUALITY OF THE ASSISTANCE RECEIVED IN OBTAINING AND COORDINATING PERSONAL FINANCIAL PLANNING BENEFITS?
#
#       num
# 42  21-22
# =======
# Q3_3D (1 questions):                                                                       given_q_text  \
# 43  DID YOU NEED ASSISTANCE IN OBTAINING AND COORDINATING TRANSPORTATION BENEFITS?
#
#       num
# 43  21-22
# =======
# Q3_3D2 (1 questions):                                                                                                given_q_text  \
# 44  WHAT WAS THE QUALITY OF THE ASSISTANCE RECEIVED IN OBTAINING AND COORDINATING TRANSPORTATION BENEFITS?
#
#       num
# 44  21-22
# =======
# Q3_3E (1 questions):                                                                       given_q_text  \
# 45  DID YOU NEED ASSISTANCE IN OBTAINING AND COORDINATING INCOME SUPPORT BENEFITS?
#
#       num
# 45  21-22
# =======
# Q3_3E2 (1 questions):                                                                                                given_q_text  \
# 46  WHAT WAS THE QUALITY OF THE ASSISTANCE RECEIVED IN OBTAINING AND COORDINATING INCOME\nSUPPORT BENEFITS?
#
#       num
# 46  21-22
# =======
# Q3_3F (1 questions):                                                              given_q_text  \
# 47  DID YOU NEED ASSISTANCE IN OBTAINING AND COORDINATING LEGAL BENEFITS?
#
#       num
# 47  21-22
# =======
# Q3_3F2 (1 questions):                                                                                       given_q_text  \
# 48  WHAT WAS THE QUALITY OF THE ASSISTANCE RECEIVED IN OBTAINING AND COORDINATING LEGAL\nBENEFITS?
#
#       num
# 48  21-22
# =======
# Q3_3G (1 questions):                                                                  given_q_text  \
# 49  DID YOU NEED ASSISTANCE IN OBTAINING AND COORDINATING CHILDCARE BENEFITS?
#
#       num
# 49  21-22
# =======
# Q3_3G2  (1 questions):                                                                                           given_q_text  \
# 50  WHAT WAS THE QUALITY OF THE ASSISTANCE RECEIVED IN OBTAINING AND COORDINATING\nCHILDCARE BENEFITS?
#
#       num
# 50  21-22
# =======
# Q3_3H (1 questions):                                                                           given_q_text  \
# 51  DID YOU NEED ASSISTANCE IN OBTAINING AND COORDINATING HOUSING COUNSELING BENEFITS?
#
#       num
# 51  21-22
# =======
# Q3_3H2 (1 questions):                                                                                                    given_q_text  \
# 52  WHAT WAS THE QUALITY OF THE ASSISTANCE RECEIVED IN OBTAINING AND COORDINATING HOUSING\nCOUNSELING BENEFITS?
#
#       num
# 52  21-22
# =======
# Q4_A (1 questions):                        given_q_text    num
# 53  DID YOU NEED RENTAL ASSISTANCE?  21-22
# =======
# Q4_A2 (1 questions):                                                given_q_text    num
# 54  WHAT WAS THE QUALITY OF THE RENTAL ASSISTANCE RECEIVED?  21-22
# =======
# Q4_B (1 questions):                                     given_q_text    num
# 55  DID YOU NEED UTILITY FEE PAYMENT ASSISTANCE?  21-22
# =======
# Q4_B2 (1 questions):                                                             given_q_text  \
# 56  WHAT WAS THE QUALITY OF THE UTILITY FEE PAYMENT ASSISTANCE RECEIVED?
#
#       num
# 56  21-22
# =======
# Q4_C (1 questions):                                               given_q_text    num
# 57  DID YOU NEED SECURITY AND UTILITY DEPOSITS ASSISTANCE?  21-22
# =======
# Q4_C2 (1 questions):                                                                       given_q_text  \
# 58  WHAT WAS THE QUALITY OF THE SECURITY AND UTILITY DEPOSITS ASSISTANCE RECEIVED?
#
#       num
# 58  21-22
# =======
# Q4_D (1 questions):                               given_q_text    num
# 59  DID YOU NEED MOVING COSTS ASSISTANCE?   21-22
# =======
# Q4_D2 (1 questions):                                                      given_q_text    num
# 60  WHAT WAS THE QUALITY OF THE MOVING COSTS ASSISTANCE RECEIVED?  21-22
# =======
# Q4_E (1 questions):                                               given_q_text    num
# 61  DID YOU NEED ASSISTANCE PURCHASING EMERGENCY SUPPLIES?  21-22
# =======
# Q4_E2 (1 questions):                                                                       given_q_text  \
# 62  WHAT WAS THE QUALITY OF THE EMERGENCY SUPPLIES PURCHASING ASSISTANCE RECEIVED?
#
#       num
# 62  21-22
# =======
# Q5 (2 questions):                                                                                                                                                                          given_q_text  \
# 64   SINCE YOU STARTED RECEIVING SERVICES FROM THIS SUPPORTIVE SERVICES PROVIDER, WAS THERE A TIME\nWHEN YOUR INCOME DECREASED SO MUCH THAT IT BECAME HARD TO PAY YOUR HOUSING COSTS?
# 361   Since you started receiving services from this supportive services provider, was there a time when your income decreased so much that it became hard to pay your housing costs?
#
#        num
# 64   21-22
# 361    NaN
# =======
# EXPERIENCE (1 questions):                                                                                                                                                 given_q_text  \
# 68  DO YOU HAVE ANY POSITIVE OR NEGATIVE EXPERIENCES YOU HAD WITH THE SSVF AGENCY OR\nSSVF STAFF WHO HELPED YOU THAT YOU WOULD LIKE TO PROVIDE COMMENTS ON?
#
#       num
# 68  21-22
# =======
# Q11A (1 questions):                                                                       given_q_text  \
# 69  DO YOU HAVE ANY ADDITIONAL SUGGESTIONS AS TO HOW TO IMPROVE THE SSVF PROGRAM?
#
#       num
# 69  21-22
# =======
# Q13 (1 questions):                      given_q_text    num
# 70  WHAT RACE DO YOU IDENTIFY AS?  21-22
# =======
# Q14 (1 questions):                           given_q_text    num
# 71  WHAT ETHNICITY DO YOU IDENTIFY AS?  21-22
# =======
# Q15 (1 questions):                       given_q_text    num
# 72  DO YOU CONSIDER YOURSELF TO BE  21-22
# =======
# Q16 (1 questions):             given_q_text    num
# 73  WHAT IS YOUR GENDER?  21-22
# =======
# ResponseID (1 questions):           given_q_text  num
# 305  Unique Identifier  NaN
# =======
# ResponseSet (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# IPAddress (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# StartDate (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# EndDate (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# RecipientLastName (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# RecipientFirstName (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# RecipientEmail (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# ExternalDataReference (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Finished (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Status (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# va Cell Phone (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Response ID (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Timestamp MM/dd/yyyy (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Custom Variable 1 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Custom Variable 2 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Custom Variable 3 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Custom Variable 4 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Respondent Email (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Region (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# How many people are in the veterans household including the veteran (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Veterans First Name if first name is not provided  please type (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Veterans Email Address yourname.com (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Cell Phone XXX-XXX-XXXX 1-999-999-9999 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# UserAgent (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q_URL (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q35 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# QIS (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# QIVA (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# F37 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8 into (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.1-1a (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.1-1b (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.1-1c_1 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.2-2a (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.2-2b (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.2-2c_1 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-a_1 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-a_2 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-a_3 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-a_4 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-a_5 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-a_6 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-a_7 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-a_8 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-b_1 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-b_2 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-b_3 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-b_4 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-b_5 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-b_6 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-b_7 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-b_8 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-c_1 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-c_2 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-c_3 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-c_4 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-c_5 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-c_6 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-c_7 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-c_8 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-a_1 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-a_2 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-a_3 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-a_4 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-a_5 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-a_6 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-a_6_TEXT (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-b_1 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-b_2 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-b_3 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-b_4 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-b_5 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-b_6 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-b_6_TEXT (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-c_1 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-c_2 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-c_3 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-c_4 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-c_5 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-c_6 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-c_6_TEXT (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q17 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q18 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Negative (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# date range (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# PIN (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Timestamp (1 questions):                              given_q_text  num
# 306  Date respondent completed the survey  NaN
# =======
# GRANT_ID (1 questions):     given_q_text  num
# 307     Grant ID  NaN
# =======
# LEGAL_NAME (1 questions):            given_q_text  num
# 308  Grantee Legal Name  NaN
# =======
# FNAME (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# PHONE (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# REMAIL (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q3_1_A (1 questions):                                     given_q_text  num
# 315  Case Management: Did you need this service?  NaN
# =======
# Q3_1_B (1 questions):                                        given_q_text  num
# 316  Case Management: Did you receive this service?  NaN
# =======
# Q3_1_C (1 questions):                                                           given_q_text  num
# 317  Case Management: What was the quality of service? Case Management  NaN
# =======
# Q3_2_A (1 questions):                                                         given_q_text  num
# 318  Assistance in obtaining VA Benefits: Did you need this service?  NaN
# =======
# Q3_2_B (1 questions):                                                            given_q_text  num
# 319  Assistance in obtaining VA Benefits: Did you receive this service?  NaN
# =======
# Q3_2_C (1 questions):                                                                                                   given_q_text  \
# 320  Assistance in obtaining VA Benefits: What was the quality of service? Assistance in obtaining VA Benefits
#
#      num
# 320  NaN
# =======
# Q3_3_1_A (1 questions):                                                                                                given_q_text  \
# 321  Assistance in obtaining and coordinating other public benefits: Did you need this service? Health care
#
#      num
# 321  NaN
# =======
# Q3_3_2_A (1 questions):                                                                                                 given_q_text  \
# 322  Assistance in obtaining and coordinating other public benefits: Did you need this service? Daily living
#
#      num
# 322  NaN
# =======
# Q3_3_3_A (1 questions):                                                                                                                given_q_text  \
# 323  Assistance in obtaining and coordinating other public benefits: Did you need this service? Personal financial planning
#
#      num
# 323  NaN
# =======
# Q3_3_4_A (1 questions):                                                                                                   given_q_text  \
# 324  Assistance in obtaining and coordinating other public benefits: Did you need this service? Transportation
#
#      num
# 324  NaN
# =======
# Q3_3_5_A (1 questions):                                                                                                   given_q_text  \
# 325  Assistance in obtaining and coordinating other public benefits: Did you need this service? Income support
#
#      num
# 325  NaN
# =======
# Q3_3_6_A (1 questions):                                                                                          given_q_text  \
# 326  Assistance in obtaining and coordinating other public benefits: Did you need this service? Legal
#
#      num
# 326  NaN
# =======
# Q3_3_7_A (1 questions):                                                                                               given_q_text  \
# 327  Assistance in obtaining and coordinating other public benefits: Did you need this service? Child care
#
#      num
# 327  NaN
# =======
# Q3_3_8_A (1 questions):                                                                                                       given_q_text  \
# 328  Assistance in obtaining and coordinating other public benefits: Did you need this service? Housing counseling
#
#      num
# 328  NaN
# =======
# Q3_3_1_B (1 questions):                                                                                                   given_q_text  \
# 329  Assistance in obtaining and coordinating other public benefits: Did you receive this service? Health care
#
#      num
# 329  NaN
# =======
# Q3_3_2_B (1 questions):                                                                                                    given_q_text  \
# 330  Assistance in obtaining and coordinating other public benefits: Did you receive this service? Daily living
#
#      num
# 330  NaN
# =======
# Q3_3_3_B (1 questions):                                                                                                                   given_q_text  \
# 331  Assistance in obtaining and coordinating other public benefits: Did you receive this service? Personal financial planning
#
#      num
# 331  NaN
# =======
# Q3_3_4_B (1 questions):                                                                                                      given_q_text  \
# 332  Assistance in obtaining and coordinating other public benefits: Did you receive this service? Transportation
#
#      num
# 332  NaN
# =======
# Q3_3_5_B (1 questions):                                                                                                      given_q_text  \
# 333  Assistance in obtaining and coordinating other public benefits: Did you receive this service? Income support
#
#      num
# 333  NaN
# =======
# Q3_3_6_B (1 questions):                                                                                             given_q_text  \
# 334  Assistance in obtaining and coordinating other public benefits: Did you receive this service? Legal
#
#      num
# 334  NaN
# =======
# Q3_3_7_B (1 questions):                                                                                                  given_q_text  \
# 335  Assistance in obtaining and coordinating other public benefits: Did you receive this service? Child care
#
#      num
# 335  NaN
# =======
# Q3_3_8_B (1 questions):                                                                                                          given_q_text  \
# 336  Assistance in obtaining and coordinating other public benefits: Did you receive this service? Housing counseling
#
#      num
# 336  NaN
# =======
# Q3_3_1_C (1 questions):                                                                                                      given_q_text  \
# 337  Assistance in obtaining and coordinating other public benefits: What was the quality of service? Health care
#
#      num
# 337  NaN
# =======
# Q3_3_2_C (1 questions):                                                                                                       given_q_text  \
# 338  Assistance in obtaining and coordinating other public benefits: What was the quality of service? Daily living
#
#      num
# 338  NaN
# =======
# Q3_3_3_C (1 questions):                                                                                                                      given_q_text  \
# 339  Assistance in obtaining and coordinating other public benefits: What was the quality of service? Personal financial planning
#
#      num
# 339  NaN
# =======
# Q3_3_4_C (1 questions):                                                                                                         given_q_text  \
# 340  Assistance in obtaining and coordinating other public benefits: What was the quality of service? Transportation
#
#      num
# 340  NaN
# =======
# Q3_3_5_C (1 questions):                                                                                                         given_q_text  \
# 341  Assistance in obtaining and coordinating other public benefits: What was the quality of service? Income support
#
#      num
# 341  NaN
# =======
# Q3_3_6_C (1 questions):                                                                                                given_q_text  \
# 342  Assistance in obtaining and coordinating other public benefits: What was the quality of service? Legal
#
#      num
# 342  NaN
# =======
# Q3_3_7_C (1 questions):                                                                                                     given_q_text  \
# 343  Assistance in obtaining and coordinating other public benefits: What was the quality of service? Child care
#
#      num
# 343  NaN
# =======
# Q3_3_8_C (1 questions):                                                                                                             given_q_text  \
# 344  Assistance in obtaining and coordinating other public benefits: What was the quality of service? Housing counseling
#
#      num
# 344  NaN
# =======
# Q3_4_1_A (1 questions):                                                                 given_q_text  \
# 345  Other Supportive Services: Did you need this service? Rental Assistance
#
#      num
# 345  NaN
# =======
# Q3_4_2_A (1 questions):                                                                              given_q_text  \
# 346  Other Supportive Services: Did you need this service? Utility fee payment assistance
#
#      num
# 346  NaN
# =======
# Q3_4_3_A (1 questions):                                                                             given_q_text  \
# 347  Other Supportive Services: Did you need this service? Security and utility deposits
#
#      num
# 347  NaN
# =======
# Q3_4_4_A (1 questions):                                                            given_q_text  num
# 348  Other Supportive Services: Did you need this service? Moving costs  NaN
# =======
# Q3_4_5_A (1 questions):                                                                              given_q_text  \
# 349  Other Supportive Services: Did you need this service? Purchase of emergency supplies
#
#      num
# 349  NaN
# =======
# Q3_4_1_B (1 questions):                                                                    given_q_text  \
# 350  Other Supportive Services: Did you receive this service? Rental Assistance
#
#      num
# 350  NaN
# =======
# Q3_4_2_B (1 questions):                                                                                 given_q_text  \
# 351  Other Supportive Services: Did you receive this service? Utility fee payment assistance
#
#      num
# 351  NaN
# =======
# Q3_4_3_B (1 questions):                                                                                given_q_text  \
# 352  Other Supportive Services: Did you receive this service? Security and utility deposits
#
#      num
# 352  NaN
# =======
# Q3_4_4_B (1 questions):                                                               given_q_text  \
# 353  Other Supportive Services: Did you receive this service? Moving costs
#
#      num
# 353  NaN
# =======
# Q3_4_5_B (1 questions):                                                                                 given_q_text  \
# 354  Other Supportive Services: Did you receive this service? Purchase of emergency supplies
#
#      num
# 354  NaN
# =======
# Q3_4_1_C (1 questions):                                                                       given_q_text  \
# 355  Other Supportive Services: What was the quality of service? Rental Assistance
#
#      num
# 355  NaN
# =======
# Q3_4_2_C (1 questions):                                                                                    given_q_text  \
# 356  Other Supportive Services: What was the quality of service? Utility fee payment assistance
#
#      num
# 356  NaN
# =======
# Q3_4_3_C (1 questions):                                                                                   given_q_text  \
# 357  Other Supportive Services: What was the quality of service? Security and utility deposits
#
#      num
# 357  NaN
# =======
# Q3_4_4_C (1 questions):                                                                  given_q_text  \
# 358  Other Supportive Services: What was the quality of service? Moving costs
#
#      num
# 358  NaN
# =======
# Q3_4_5_C (1 questions):                                                                                    given_q_text  \
# 359  Other Supportive Services: What was the quality of service? Purchase of emergency supplies
#
#      num
# 359  NaN
# =======
# DateRange (1 questions):                            given_q_text  num
# 368  Month in which survey was reported  NaN
# =======
# UNIQUEID (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# GRANTEEID (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# MODE (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# LtCallDt (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# LtCallST (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# CallDurS (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# CallDurM (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# TotalTime (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# LtCallR (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# LtCaseR (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Date (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# HOUSEHOLD (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# HEALTHCARE (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# HEALTHCARE2 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q1 Num (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q3_3G2 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# INT99 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q12 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# INT (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======

# %%
#*RESULTS FOR QS WITH THE SAME LABEL BUT DIFFERENT TEXT VALUES (DEFINITIONS):

#Q1: A presumably insignificant change in 21-22, from "this ssvf agency" to "this supportive services provider."

#Q2: There's an inconsistency. In the pdfs for 16 and for 17, Q2 asks if the participant would
#recommend the services provider to a friend or veteran. However, in the pdf for 21-22 and the data dictionary, it
#changes and asks if the SSVF case manager involved the participant in creating an individualized housing
#stabilization plan. Also, in the data dictionary, it refers to the "supportive services provider" rather than
#the "SSVF case manager." I would think they're referring to the same thing, but in my head, they mean different
#things.

#Q4: There's an inconsistency. In the pdfs for 16 and for 17, Q4 asks if the participant would return to
#the supportive services provider at no cost if she/he/they need help again. But in the pdf for 21-22 as well as 
#the data dictionary, Q4 instead asks if the SSVF case manager/supportive services provider involved the
#participant in creating an individualized housing stabilization plan. (The 20-22 pdf refers to the subject
#as "this SSVF agency," whereas the data dict refers to the subject as "the supportive services provider."
#I presume this is an insignificant change.)

#Q7: There's an inconsistency. In the pdfs for 16 and for 17, it asks for additional feedback about the supportive
#services provider. However, in the pdfs for 18, 20 and 21-22 as well as in the data dictionary, it instead asks
#how satisfied the participant is with the courteousness of the staff dealt with most often.

#Q8: There's an inconsistency. The pdf for 16 asks about supportive services received and their quality, whereas 
#the pdfs for 18, 20 and 21-22 are about timeliness of communication of the person the participant dealt with the most.

#Q9, Q10 and Q11: Appears insignificant, but just noting that the pdf for 21-22 has unusual prose. Presumably,
#these are all the same, though.

#QA: Presumably insignificant, but noting that for the pdf for 21-22, it asks for the number of people in the 
#household, whereas in the data dictionary, it asks for the number of individuals receiving support services 
#from the provider.

#*basically the end of of my looking into questions with multiple definitions

# %%
#Redoing it with normalized letters (uppercasing them):

q_num_list = []

for q_num in dlp_qs["given_q_label"].str.upper(): #for each question label
    if q_num in q_num_list:
        continue #if I already appended the question label (below), skip
    else:
        qs_per_num = ( #create a Series of questions for each q_num
            dlp_qs[
            (dlp_qs["given_q_label"].str.upper() == q_num) #filter to only include the given q number
            &
            (
                (dlp_qs["source_type"] == "pdf")
            |
                (dlp_qs["source_type"] == "data dictionary")
            )
                #filter to only include pdfs and the data dictionary (since only those have question text)
        ]
        [["given_q_text", "num"]] #show the question text and their numbers
        )
        number_of_qs_per_num = len(qs_per_num)
        q_num_list.append(q_num)
        print(f'{q_num} ({number_of_qs_per_num} questions): {qs_per_num}')
        print("=======")
# Out:
# Q1 (6 questions):                                                                                                   given_q_text  \
# 0    How would you rate the quality of the services you have\nreceived from this supportive services provider?
# 7    How would you rate the quality of the services you have\nreceived from this supportive services provider?
# 13   How would you rate the quality of the services you have\nreceived from this supportive services provider?
# 20    How would you rate the quality of the services you have received from this supportive services provider?
# 30                         HOW WOULD YOU RATE THE QUALITY OF SERVICES YOU HAVE RECEIVED FROM THIS SSVF AGENCY?
# 312   How would you rate the quality of the services you have received from this supportive services provider?
#
#        num
# 0       16
# 7       17
# 13      18
# 20      20
# 30   21-22
# 312    NaN
# =======
# Q2 (4 questions):                                                                                                                             given_q_text  \
# 1    If another Veteran or a friend were in need of similar\nhelp, would you recommend this supportive services provider\nto him or her?
# 8    If another Veteran or a friend were in need of similar help,\nwould you recommend this supportive services provider to him or\nher?
# 31                                      DID THE SSVF CASE MANAGER INVOLVE YOU IN CREATING AN INDIVIDUALIZED HOUSING STABILIZATION\nPLAN?
# 313                           Did the supportive services provider involve you in creating an individualized housing stabilization plan?
#
#        num
# 1       16
# 8       17
# 31   21-22
# 313    NaN
# =======
# Q3 (2 questions):                                                                                          given_q_text  \
# 2  How satisfied are you with the services you have\nreceived from this supportive services provider?
# 9  How satisfied are you with the services you have received\nfrom this supportive services provider?
#
#   num
# 2  16
# 9  17
# =======
# Q4 (4 questions):                                                                                                                              given_q_text  \
# 3    If you needed help again and had a choice of where to\ngo at no cost to you, would you return to this supportive\nservices provider?
# 10   If you needed help again and had a choice of where to go at\nno cost to you, would you return to this supportive services\nprovider?
# 63                                            HOW MANY TIMES HAVE YOU MOVED SINCE YOU STARTED RECEIVING SERVICES FROM THIS SSVF AGENCY?\n
# 360                                                How many times have you moved since you started receiving services from this provider?
#
#        num
# 3       16
# 10      17
# 63   21-22
# 360    NaN
# =======
# Q6ABC (2 questions):                                                                                                                                                                                                                                                                                                                                                                                                                                     given_q_text  \
# 4   Veterans were asked a series of questions about which supportive services they needed and\nreceived. If they received the service, they were then asked about the quality of the service.\nAfter answering questions about fifteen different specific services (inclusive of such things as\ncase management, health care and rental assistance), they were given the option to write in\nservices not mentioned that they felt they needed.
# 11  Veterans were asked a series of questions about which supportive services they needed and\nreceived. If they received the service, they were then asked about the quality of the service.\nAfter answering questions about fifteen different specific services (inclusive of such things as\ncase management, health care and rental assistance), they were given the option to write in\nservices not mentioned that they felt they needed.
#
#    num
# 4   16
# 11  17
# =======
# Q7 (6 questions):                                                                                                                                     given_q_text  \
# 5                                       Is there any other feedback\nabout the supportive services provider that\nyou wish to provide to the VA?
# 12                                      Is there any other feedback\nabout the supportive services provider that\nyou wish to provide to the VA?
# 15   How satisfied are you with the courteousness of the staff person that you dealt with most often\nwhile you were working with this provider?
# 22   How satisfied are you with the courteousness of the staff person that you dealt with most often\nwhile you were working with this provider?
# 66   HOW SATISFIED ARE YOU WITH THE COURTEOUSNESS OF THE STAFF PERSON THAT YOU DEALT WITH MOST\nOFTEN WHILE YOU WERE WORKING WITH THIS PROVIDER?
# 363   How satisfied are you with the courteousness of the staff person that you dealt with most often while you were working with this provider?
#
#        num
# 5       16
# 12      17
# 15      18
# 22      20
# 66   21-22
# 363    NaN
# =======
# Q8 (5 questions):                                                                                                                                                     given_q_text  \
# 6                                           Please indicate which supportive services you received and indicate the quality of the supportive services received.
# 16   How satisfied are you with the timeliness of communication with the staff person that you dealt\nwith most often while you were working with this provider?
# 23   How satisfied are you with the timeliness of communication with the staff person that you dealt\nwith most often while you were working with this provider?
# 67   HOW SATISFIED ARE YOU WITH THE TIMELINESS OF COMMUNICATION WITH THE STAFF PERSON THAT YOU\nDEALT WITH MOST OFTEN WHILE YOU WERE WORKING WITH THIS PROVIDER?
# 364   How satisfied are you with the timeliness of communication with the staff person that you dealt with most often while you were working with this provider?
#
#        num
# 6       16
# 16      18
# 23      20
# 67   21-22
# 364    NaN
# =======
# Q6 (4 questions):                                                                                                                          given_q_text  \
# 14   How satisfied are you with the courteousness of the staff person that you initially spoke with when\nyou contacted the provider?
# 21   How satisfied are you with the courteousness of the staff person that you initially spoke with when\nyou contacted the provider?
# 65   HOW SATISFIED ARE YOU WITH THE COURTEOUSNESS OF THE STAFF PERSON THAT YOU INITIALLY SPOKE\nWITH WHEN YOU CONTACTED THE PROVIDER?
# 362   How satisfied are you with the courteousness of the staff person that you initially spoke with when you contacted the provider?
#
#        num
# 14      18
# 21      20
# 65   21-22
# 362    NaN
# =======
# Q9 (4 questions):                                                                                        given_q_text  \
# 17   If your experiences were positive with this supportive services provider,\nplease tell us why.
# 24   If your experiences were positive with this supportive services provider,\nplease tell us why.
# 74                       Appendix A: Q9_Positive experiences with the S.S.V.F staff that helped you
# 365   If your experiences were positive with this supportive services provider, please tell us why.
#
#        num
# 17      18
# 24      20
# 74   21-22
# 365    NaN
# =======
# Q10 (4 questions):                                                                                                given_q_text  \
# 18           If your experiences were negative with this supportive services\nprovider, please tell us why.
# 25           If your experiences were negative with this supportive services\nprovider, please tell us why.
# 75   Appendix B: Q10_Negative experiences you had with the SSVF agency or S. S. V. F.\nstaff who helped you
# 366           If your experiences were negative with this supportive services provider, please tell us why.
#
#        num
# 18      18
# 25      20
# 75   21-22
# 366    NaN
# =======
# Q11 (4 questions):                                                                        given_q_text  \
# 19   Please list any additional suggestions as to how to improve the SSVF\nProgram.
# 26   Please list any additional suggestions as to how to improve the SSVF\nProgram.
# 76                       Appendix C: Q11_Suggestions to improve the S.S.V.F program
# 367   Please list any additional suggestions as to how to improve the SSVF Program.
#
#        num
# 19      18
# 26      20
# 76   21-22
# 367    NaN
# =======
# QA (2 questions):                                                                                                given_q_text  \
# 27                                                     WHAT IS THE NUMBER OF INDIVIDUALS IN YOUR HOUSEHOLD?
# 309  Number of individuals (including yourself) in household receiving support services from this provider:
#
#        num
# 27   21-22
# 309    NaN
# =======
# QB (2 questions):                                        given_q_text    num
# 28   ARE YOU ENROLLED IN THE VA HEALTH CARE SYSTEM?  21-22
# 310  Are you enrolled in the VA health care system?    NaN
# =======
# QC (2 questions):                                                                                        given_q_text  \
# 29   WERE YOU ENROLLED IN THE VA HEALTHCARE SYSTEM PRIOR TO RECEIVING SERVICES FROM THIS\nPROVIDER?
# 311  Were you enrolled in the VA health care system prior to receiving services from this provider?
#
#        num
# 29   21-22
# 311    NaN
# =======
# Q2A (2 questions):                                                          given_q_text    num
# 32   DO YOU FEEL THAT THIS HOUSING PLAN IS A GOOD FIT FOR YOUR NEEDS?  21-22
# 314  Do you feel that this housing plan is a good fit for your needs?    NaN
# =======
# Q3_1 (1 questions):                      given_q_text    num
# 33  DID YOU NEED CASE MANAGEMENT?  21-22
# =======
# Q3_1B (1 questions):                                              given_q_text    num
# 34  WHAT WAS THE QUALITY OF THE CASE MANAGEMENT RECEIVED?  21-22
# =======
# Q3_2 (1 questions):                                          given_q_text    num
# 35  DID YOU NEED ASSISTANCE IN OBTAINING VA BENEFITS?  21-22
# =======
# Q3_2B (1 questions):                                                              given_q_text  \
# 36  WHAT WAS THE QUALITY OF ASSISTANCE RECEIVED IN OBTAINING VA BENEFITS?
#
#       num
# 36  21-22
# =======
# Q3_3A (1 questions):                                                                    given_q_text  \
# 37  DID YOU NEED ASSISTANCE IN OBTAINING AND COORDINATING HEALTH CARE BENEFITS?
#
#       num
# 37  21-22
# =======
# Q3_3A2 (1 questions):                                                                                            given_q_text  \
# 38  WHAT WAS THE QUALITY OF THE ASSISTANCE RECEIVED IN OBTAINING AND COORDINATING\nHEALTHCARE BENEFITS?
#
#       num
# 38  21-22
# =======
# Q3_3B (1 questions):                                                                     given_q_text  \
# 39  DID YOU NEED ASSISTANCE IN OBTAINING AND COORDINATING DAILY LIVING BENEFITS?
#
#       num
# 39  21-22
# =======
# Q3_3B2 (1 questions):                                                                                              given_q_text  \
# 40  WHAT WAS THE QUALITY OF THE ASSISTANCE RECEIVED IN OBTAINING AND COORDINATING DAILY\nLIVING BENEFITS?
#
#       num
# 40  21-22
# =======
# Q3_3C (1 questions):                                                                                     given_q_text  \
# 41  DID YOU NEED ASSISTANCE IN OBTAINING AND COORDINATING PERSONAL FINANCIAL PLANNING\nBENEFITS?
#
#       num
# 41  21-22
# =======
# Q3_3C2 (1 questions):                                                                                                            given_q_text  \
# 42  WHAT WAS THE QUALITY OF THE ASSISTANCE RECEIVED IN OBTAINING AND COORDINATING PERSONAL FINANCIAL PLANNING BENEFITS?
#
#       num
# 42  21-22
# =======
# Q3_3D (1 questions):                                                                       given_q_text  \
# 43  DID YOU NEED ASSISTANCE IN OBTAINING AND COORDINATING TRANSPORTATION BENEFITS?
#
#       num
# 43  21-22
# =======
# Q3_3D2 (1 questions):                                                                                                given_q_text  \
# 44  WHAT WAS THE QUALITY OF THE ASSISTANCE RECEIVED IN OBTAINING AND COORDINATING TRANSPORTATION BENEFITS?
#
#       num
# 44  21-22
# =======
# Q3_3E (1 questions):                                                                       given_q_text  \
# 45  DID YOU NEED ASSISTANCE IN OBTAINING AND COORDINATING INCOME SUPPORT BENEFITS?
#
#       num
# 45  21-22
# =======
# Q3_3E2 (1 questions):                                                                                                given_q_text  \
# 46  WHAT WAS THE QUALITY OF THE ASSISTANCE RECEIVED IN OBTAINING AND COORDINATING INCOME\nSUPPORT BENEFITS?
#
#       num
# 46  21-22
# =======
# Q3_3F (1 questions):                                                              given_q_text  \
# 47  DID YOU NEED ASSISTANCE IN OBTAINING AND COORDINATING LEGAL BENEFITS?
#
#       num
# 47  21-22
# =======
# Q3_3F2 (1 questions):                                                                                       given_q_text  \
# 48  WHAT WAS THE QUALITY OF THE ASSISTANCE RECEIVED IN OBTAINING AND COORDINATING LEGAL\nBENEFITS?
#
#       num
# 48  21-22
# =======
# Q3_3G (1 questions):                                                                  given_q_text  \
# 49  DID YOU NEED ASSISTANCE IN OBTAINING AND COORDINATING CHILDCARE BENEFITS?
#
#       num
# 49  21-22
# =======
# Q3_3G2  (1 questions):                                                                                           given_q_text  \
# 50  WHAT WAS THE QUALITY OF THE ASSISTANCE RECEIVED IN OBTAINING AND COORDINATING\nCHILDCARE BENEFITS?
#
#       num
# 50  21-22
# =======
# Q3_3H (1 questions):                                                                           given_q_text  \
# 51  DID YOU NEED ASSISTANCE IN OBTAINING AND COORDINATING HOUSING COUNSELING BENEFITS?
#
#       num
# 51  21-22
# =======
# Q3_3H2 (1 questions):                                                                                                    given_q_text  \
# 52  WHAT WAS THE QUALITY OF THE ASSISTANCE RECEIVED IN OBTAINING AND COORDINATING HOUSING\nCOUNSELING BENEFITS?
#
#       num
# 52  21-22
# =======
# Q4_A (1 questions):                        given_q_text    num
# 53  DID YOU NEED RENTAL ASSISTANCE?  21-22
# =======
# Q4_A2 (1 questions):                                                given_q_text    num
# 54  WHAT WAS THE QUALITY OF THE RENTAL ASSISTANCE RECEIVED?  21-22
# =======
# Q4_B (1 questions):                                     given_q_text    num
# 55  DID YOU NEED UTILITY FEE PAYMENT ASSISTANCE?  21-22
# =======
# Q4_B2 (1 questions):                                                             given_q_text  \
# 56  WHAT WAS THE QUALITY OF THE UTILITY FEE PAYMENT ASSISTANCE RECEIVED?
#
#       num
# 56  21-22
# =======
# Q4_C (1 questions):                                               given_q_text    num
# 57  DID YOU NEED SECURITY AND UTILITY DEPOSITS ASSISTANCE?  21-22
# =======
# Q4_C2 (1 questions):                                                                       given_q_text  \
# 58  WHAT WAS THE QUALITY OF THE SECURITY AND UTILITY DEPOSITS ASSISTANCE RECEIVED?
#
#       num
# 58  21-22
# =======
# Q4_D (1 questions):                               given_q_text    num
# 59  DID YOU NEED MOVING COSTS ASSISTANCE?   21-22
# =======
# Q4_D2 (1 questions):                                                      given_q_text    num
# 60  WHAT WAS THE QUALITY OF THE MOVING COSTS ASSISTANCE RECEIVED?  21-22
# =======
# Q4_E (1 questions):                                               given_q_text    num
# 61  DID YOU NEED ASSISTANCE PURCHASING EMERGENCY SUPPLIES?  21-22
# =======
# Q4_E2 (1 questions):                                                                       given_q_text  \
# 62  WHAT WAS THE QUALITY OF THE EMERGENCY SUPPLIES PURCHASING ASSISTANCE RECEIVED?
#
#       num
# 62  21-22
# =======
# Q5 (2 questions):                                                                                                                                                                          given_q_text  \
# 64   SINCE YOU STARTED RECEIVING SERVICES FROM THIS SUPPORTIVE SERVICES PROVIDER, WAS THERE A TIME\nWHEN YOUR INCOME DECREASED SO MUCH THAT IT BECAME HARD TO PAY YOUR HOUSING COSTS?
# 361   Since you started receiving services from this supportive services provider, was there a time when your income decreased so much that it became hard to pay your housing costs?
#
#        num
# 64   21-22
# 361    NaN
# =======
# EXPERIENCE (1 questions):                                                                                                                                                 given_q_text  \
# 68  DO YOU HAVE ANY POSITIVE OR NEGATIVE EXPERIENCES YOU HAD WITH THE SSVF AGENCY OR\nSSVF STAFF WHO HELPED YOU THAT YOU WOULD LIKE TO PROVIDE COMMENTS ON?
#
#       num
# 68  21-22
# =======
# Q11A (1 questions):                                                                       given_q_text  \
# 69  DO YOU HAVE ANY ADDITIONAL SUGGESTIONS AS TO HOW TO IMPROVE THE SSVF PROGRAM?
#
#       num
# 69  21-22
# =======
# Q13 (1 questions):                      given_q_text    num
# 70  WHAT RACE DO YOU IDENTIFY AS?  21-22
# =======
# Q14 (1 questions):                           given_q_text    num
# 71  WHAT ETHNICITY DO YOU IDENTIFY AS?  21-22
# =======
# Q15 (1 questions):                       given_q_text    num
# 72  DO YOU CONSIDER YOURSELF TO BE  21-22
# =======
# Q16 (1 questions):             given_q_text    num
# 73  WHAT IS YOUR GENDER?  21-22
# =======
# RESPONSEID (1 questions):           given_q_text  num
# 305  Unique Identifier  NaN
# =======
# RESPONSESET (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# IPADDRESS (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# STARTDATE (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# ENDDATE (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# RECIPIENTLASTNAME (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# RECIPIENTFIRSTNAME (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# RECIPIENTEMAIL (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# EXTERNALDATAREFERENCE (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# FINISHED (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# STATUS (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# VA CELL PHONE (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# RESPONSE ID (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# TIMESTAMP MM/DD/YYYY (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# CUSTOM VARIABLE 1 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# CUSTOM VARIABLE 2 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# CUSTOM VARIABLE 3 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# CUSTOM VARIABLE 4 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# RESPONDENT EMAIL (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# REGION (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# HOW MANY PEOPLE ARE IN THE VETERANS HOUSEHOLD INCLUDING THE VETERAN (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# VETERANS FIRST NAME IF FIRST NAME IS NOT PROVIDED  PLEASE TYPE (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# VETERANS EMAIL ADDRESS YOURNAME.COM (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# CELL PHONE XXX-XXX-XXXX 1-999-999-9999 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# USERAGENT (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q_URL (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q35 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# QIS (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# QIVA (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# F37 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8 INTO (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.1-1A (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.1-1B (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.1-1C_1 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.2-2A (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.2-2B (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.2-2C_1 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-A_1 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-A_2 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-A_3 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-A_4 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-A_5 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-A_6 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-A_7 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-A_8 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-B_1 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-B_2 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-B_3 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-B_4 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-B_5 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-B_6 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-B_7 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-B_8 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-C_1 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-C_2 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-C_3 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-C_4 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-C_5 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-C_6 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-C_7 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.3-C_8 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-A_1 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-A_2 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-A_3 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-A_4 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-A_5 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-A_6 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-A_6_TEXT (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-B_1 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-B_2 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-B_3 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-B_4 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-B_5 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-B_6 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-B_6_TEXT (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-C_1 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-C_2 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-C_3 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-C_4 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-C_5 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-C_6 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q8.4-C_6_TEXT (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q17 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q18 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# NEGATIVE (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# DATE RANGE (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# PIN (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# TIMESTAMP (1 questions):                              given_q_text  num
# 306  Date respondent completed the survey  NaN
# =======
# GRANT_ID (1 questions):     given_q_text  num
# 307     Grant ID  NaN
# =======
# LEGAL_NAME (1 questions):            given_q_text  num
# 308  Grantee Legal Name  NaN
# =======
# FNAME (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# PHONE (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# REMAIL (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q3_1_A (1 questions):                                     given_q_text  num
# 315  Case Management: Did you need this service?  NaN
# =======
# Q3_1_B (1 questions):                                        given_q_text  num
# 316  Case Management: Did you receive this service?  NaN
# =======
# Q3_1_C (1 questions):                                                           given_q_text  num
# 317  Case Management: What was the quality of service? Case Management  NaN
# =======
# Q3_2_A (1 questions):                                                         given_q_text  num
# 318  Assistance in obtaining VA Benefits: Did you need this service?  NaN
# =======
# Q3_2_B (1 questions):                                                            given_q_text  num
# 319  Assistance in obtaining VA Benefits: Did you receive this service?  NaN
# =======
# Q3_2_C (1 questions):                                                                                                   given_q_text  \
# 320  Assistance in obtaining VA Benefits: What was the quality of service? Assistance in obtaining VA Benefits
#
#      num
# 320  NaN
# =======
# Q3_3_1_A (1 questions):                                                                                                given_q_text  \
# 321  Assistance in obtaining and coordinating other public benefits: Did you need this service? Health care
#
#      num
# 321  NaN
# =======
# Q3_3_2_A (1 questions):                                                                                                 given_q_text  \
# 322  Assistance in obtaining and coordinating other public benefits: Did you need this service? Daily living
#
#      num
# 322  NaN
# =======
# Q3_3_3_A (1 questions):                                                                                                                given_q_text  \
# 323  Assistance in obtaining and coordinating other public benefits: Did you need this service? Personal financial planning
#
#      num
# 323  NaN
# =======
# Q3_3_4_A (1 questions):                                                                                                   given_q_text  \
# 324  Assistance in obtaining and coordinating other public benefits: Did you need this service? Transportation
#
#      num
# 324  NaN
# =======
# Q3_3_5_A (1 questions):                                                                                                   given_q_text  \
# 325  Assistance in obtaining and coordinating other public benefits: Did you need this service? Income support
#
#      num
# 325  NaN
# =======
# Q3_3_6_A (1 questions):                                                                                          given_q_text  \
# 326  Assistance in obtaining and coordinating other public benefits: Did you need this service? Legal
#
#      num
# 326  NaN
# =======
# Q3_3_7_A (1 questions):                                                                                               given_q_text  \
# 327  Assistance in obtaining and coordinating other public benefits: Did you need this service? Child care
#
#      num
# 327  NaN
# =======
# Q3_3_8_A (1 questions):                                                                                                       given_q_text  \
# 328  Assistance in obtaining and coordinating other public benefits: Did you need this service? Housing counseling
#
#      num
# 328  NaN
# =======
# Q3_3_1_B (1 questions):                                                                                                   given_q_text  \
# 329  Assistance in obtaining and coordinating other public benefits: Did you receive this service? Health care
#
#      num
# 329  NaN
# =======
# Q3_3_2_B (1 questions):                                                                                                    given_q_text  \
# 330  Assistance in obtaining and coordinating other public benefits: Did you receive this service? Daily living
#
#      num
# 330  NaN
# =======
# Q3_3_3_B (1 questions):                                                                                                                   given_q_text  \
# 331  Assistance in obtaining and coordinating other public benefits: Did you receive this service? Personal financial planning
#
#      num
# 331  NaN
# =======
# Q3_3_4_B (1 questions):                                                                                                      given_q_text  \
# 332  Assistance in obtaining and coordinating other public benefits: Did you receive this service? Transportation
#
#      num
# 332  NaN
# =======
# Q3_3_5_B (1 questions):                                                                                                      given_q_text  \
# 333  Assistance in obtaining and coordinating other public benefits: Did you receive this service? Income support
#
#      num
# 333  NaN
# =======
# Q3_3_6_B (1 questions):                                                                                             given_q_text  \
# 334  Assistance in obtaining and coordinating other public benefits: Did you receive this service? Legal
#
#      num
# 334  NaN
# =======
# Q3_3_7_B (1 questions):                                                                                                  given_q_text  \
# 335  Assistance in obtaining and coordinating other public benefits: Did you receive this service? Child care
#
#      num
# 335  NaN
# =======
# Q3_3_8_B (1 questions):                                                                                                          given_q_text  \
# 336  Assistance in obtaining and coordinating other public benefits: Did you receive this service? Housing counseling
#
#      num
# 336  NaN
# =======
# Q3_3_1_C (1 questions):                                                                                                      given_q_text  \
# 337  Assistance in obtaining and coordinating other public benefits: What was the quality of service? Health care
#
#      num
# 337  NaN
# =======
# Q3_3_2_C (1 questions):                                                                                                       given_q_text  \
# 338  Assistance in obtaining and coordinating other public benefits: What was the quality of service? Daily living
#
#      num
# 338  NaN
# =======
# Q3_3_3_C (1 questions):                                                                                                                      given_q_text  \
# 339  Assistance in obtaining and coordinating other public benefits: What was the quality of service? Personal financial planning
#
#      num
# 339  NaN
# =======
# Q3_3_4_C (1 questions):                                                                                                         given_q_text  \
# 340  Assistance in obtaining and coordinating other public benefits: What was the quality of service? Transportation
#
#      num
# 340  NaN
# =======
# Q3_3_5_C (1 questions):                                                                                                         given_q_text  \
# 341  Assistance in obtaining and coordinating other public benefits: What was the quality of service? Income support
#
#      num
# 341  NaN
# =======
# Q3_3_6_C (1 questions):                                                                                                given_q_text  \
# 342  Assistance in obtaining and coordinating other public benefits: What was the quality of service? Legal
#
#      num
# 342  NaN
# =======
# Q3_3_7_C (1 questions):                                                                                                     given_q_text  \
# 343  Assistance in obtaining and coordinating other public benefits: What was the quality of service? Child care
#
#      num
# 343  NaN
# =======
# Q3_3_8_C (1 questions):                                                                                                             given_q_text  \
# 344  Assistance in obtaining and coordinating other public benefits: What was the quality of service? Housing counseling
#
#      num
# 344  NaN
# =======
# Q3_4_1_A (1 questions):                                                                 given_q_text  \
# 345  Other Supportive Services: Did you need this service? Rental Assistance
#
#      num
# 345  NaN
# =======
# Q3_4_2_A (1 questions):                                                                              given_q_text  \
# 346  Other Supportive Services: Did you need this service? Utility fee payment assistance
#
#      num
# 346  NaN
# =======
# Q3_4_3_A (1 questions):                                                                             given_q_text  \
# 347  Other Supportive Services: Did you need this service? Security and utility deposits
#
#      num
# 347  NaN
# =======
# Q3_4_4_A (1 questions):                                                            given_q_text  num
# 348  Other Supportive Services: Did you need this service? Moving costs  NaN
# =======
# Q3_4_5_A (1 questions):                                                                              given_q_text  \
# 349  Other Supportive Services: Did you need this service? Purchase of emergency supplies
#
#      num
# 349  NaN
# =======
# Q3_4_1_B (1 questions):                                                                    given_q_text  \
# 350  Other Supportive Services: Did you receive this service? Rental Assistance
#
#      num
# 350  NaN
# =======
# Q3_4_2_B (1 questions):                                                                                 given_q_text  \
# 351  Other Supportive Services: Did you receive this service? Utility fee payment assistance
#
#      num
# 351  NaN
# =======
# Q3_4_3_B (1 questions):                                                                                given_q_text  \
# 352  Other Supportive Services: Did you receive this service? Security and utility deposits
#
#      num
# 352  NaN
# =======
# Q3_4_4_B (1 questions):                                                               given_q_text  \
# 353  Other Supportive Services: Did you receive this service? Moving costs
#
#      num
# 353  NaN
# =======
# Q3_4_5_B (1 questions):                                                                                 given_q_text  \
# 354  Other Supportive Services: Did you receive this service? Purchase of emergency supplies
#
#      num
# 354  NaN
# =======
# Q3_4_1_C (1 questions):                                                                       given_q_text  \
# 355  Other Supportive Services: What was the quality of service? Rental Assistance
#
#      num
# 355  NaN
# =======
# Q3_4_2_C (1 questions):                                                                                    given_q_text  \
# 356  Other Supportive Services: What was the quality of service? Utility fee payment assistance
#
#      num
# 356  NaN
# =======
# Q3_4_3_C (1 questions):                                                                                   given_q_text  \
# 357  Other Supportive Services: What was the quality of service? Security and utility deposits
#
#      num
# 357  NaN
# =======
# Q3_4_4_C (1 questions):                                                                  given_q_text  \
# 358  Other Supportive Services: What was the quality of service? Moving costs
#
#      num
# 358  NaN
# =======
# Q3_4_5_C (1 questions):                                                                                    given_q_text  \
# 359  Other Supportive Services: What was the quality of service? Purchase of emergency supplies
#
#      num
# 359  NaN
# =======
# DATERANGE (1 questions):                            given_q_text  num
# 368  Month in which survey was reported  NaN
# =======
# UNIQUEID (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# GRANTEEID (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# MODE (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# LTCALLDT (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# LTCALLST (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# CALLDURS (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# CALLDURM (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# TOTALTIME (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# LTCALLR (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# LTCASER (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# DATE (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# HOUSEHOLD (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# HEALTHCARE (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# HEALTHCARE2 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q1 NUM (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q3_3G2 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# INT99 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# Q12 (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======
# INT (0 questions): Empty DataFrame
# Columns: [given_q_text, num]
# Index: []
# =======

# %%
#OK, I checked manually. The question counts per question are the same. 
#Therefore, normalizing the q labels in that loop didn't make 
#a difference.

# %%
#However, let's figure out whether we need to normalize the labels when accounting for all of the labels
# — not just the ones we filtered for in the loop:

# %%
not_normalized_label_counts = (
    dlp_qs["given_q_label"]
    .value_counts()
    .to_frame()
    .reset_index()
)
not_normalized_label_counts.head()
# Out:
#   given_q_label  count
# 0            Q1      9
# 1            Q7      9
# 2            Q4      7
# 3            Q8      7
# 4            Q6      7

# %%
normalized_label_counts = (
    dlp_qs["given_q_label"]
    .str.upper()
    .value_counts()
    .to_frame()
    .reset_index()
)
normalized_label_counts.head()
# Out:
#   given_q_label  count
# 0            Q1      9
# 1            Q7      9
# 2            Q4      7
# 3            Q8      7
# 4            Q6      7

# %%
(
    not_normalized_label_counts
    ["given_q_label"] 
    == 
    normalized_label_counts
    ["given_q_label"]
).value_counts()
#Looks like there are some values that are different when uppercased.
#I'll have to stay wary of that.
# Out:
# given_q_label
# True     119
# False     91
# Name: count, dtype: int64

# %%
dlp_qs = (
    dlp_qs
    .merge(not_normalized_label_counts)
    .rename(columns={"count" : "not_normalized_label_counts"})
)
dlp_qs.head()
# Out:
#   given_q_label  \
# 0            Q1
# 1            Q1
# 2            Q1
# 3            Q1
# 4            Q1
#
#                                                                                                 given_q_text  \
# 0  How would you rate the quality of the services you have\nreceived from this supportive services provider?
# 1  How would you rate the quality of the services you have\nreceived from this supportive services provider?
# 2  How would you rate the quality of the services you have\nreceived from this supportive services provider?
# 3   How would you rate the quality of the services you have received from this supportive services provider?
# 4                        HOW WOULD YOU RATE THE QUALITY OF SERVICES YOU HAVE RECEIVED FROM THIS SSVF AGENCY?
#
#   source_type    num  percent_nonnull  consistent/inconsistent  dlp_std_q  \
# 0         pdf     16              NaN                      NaN        NaN
# 1         pdf     17              NaN                      NaN        NaN
# 2         pdf     18              NaN                      NaN        NaN
# 3         pdf     20              NaN                      NaN        NaN
# 4         pdf  21-22              NaN                      NaN        NaN
#
#    dlp_id_for_std_q  dlp_qid_all_qs (index)  \
# 0               NaN                     NaN
# 1               NaN                     NaN
# 2               NaN                     NaN
# 3               NaN                     NaN
# 4               NaN                     NaN
#
#                                    notes  not_normalized_label_counts
# 0  The PDF looks at Qs1 thru 4 together.                            9
# 1  The PDF looks at Qs1 thru 4 together.                            9
# 2                                    NaN                            9
# 3                                    NaN                            9
# 4                                    NaN                            9

# %%
#To add the count to a DataFrame:
counted_dlp_qs = (
    normalized_label_counts
    .assign(normalized_dlp_label = ( #this will be the key column they'll merge on
        lambda df: (
            df["given_q_label"] #defining normalized_dlp label as given_q_label
        ))) #end of assignment
    .drop(columns=["given_q_label"]) #dropping the given_q_label to only keep the count
    .merge #Now, they're merge on normalized_dlp_label
(
    dlp_qs
    .assign(
    normalized_dlp_label = lambda df: (
        df["given_q_label"] #adding the same column to this table to ensure the dfs merge
        .str.upper() 
    ) #end of this column's assignment
    ) #end of assign function
    ,
    on="normalized_dlp_label"
)
    .rename(columns={"count" : "normalized_label_counts"})
    [[ #reorganizing the columns a bit
        "given_q_label",
        "given_q_text",
        "source_type",
        "num",
        "percent_nonnull",
        "consistent/inconsistent",
        "dlp_std_q",
        "dlp_id_for_std_q",
        "dlp_qid_all_qs (index)",
        "notes",
        "given_q_text",
        "normalized_dlp_label",
        "normalized_label_counts",
        "not_normalized_label_counts"
        
    ]]
)

# %%
#*start of my looking directly into which questions don't have a definition
counted_dlp_qs.head()
# Out:
#   given_q_label  \
# 0            Q1
# 1            Q1
# 2            Q1
# 3            Q1
# 4            Q1
#
#                                                                                                 given_q_text  \
# 0  How would you rate the quality of the services you have\nreceived from this supportive services provider?
# 1  How would you rate the quality of the services you have\nreceived from this supportive services provider?
# 2  How would you rate the quality of the services you have\nreceived from this supportive services provider?
# 3   How would you rate the quality of the services you have received from this supportive services provider?
# 4                        HOW WOULD YOU RATE THE QUALITY OF SERVICES YOU HAVE RECEIVED FROM THIS SSVF AGENCY?
#
#   source_type    num  percent_nonnull  consistent/inconsistent  dlp_std_q  \
# 0         pdf     16              NaN                      NaN        NaN
# 1         pdf     17              NaN                      NaN        NaN
# 2         pdf     18              NaN                      NaN        NaN
# 3         pdf     20              NaN                      NaN        NaN
# 4         pdf  21-22              NaN                      NaN        NaN
#
#    dlp_id_for_std_q  dlp_qid_all_qs (index)  \
# 0               NaN                     NaN
# 1               NaN                     NaN
# 2               NaN                     NaN
# 3               NaN                     NaN
# 4               NaN                     NaN
#
#                                    notes  \
# 0  The PDF looks at Qs1 thru 4 together.
# 1  The PDF looks at Qs1 thru 4 together.
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#                                                                                                 given_q_text  \
# 0  How would you rate the quality of the services you have\nreceived from this supportive services provider?
# 1  How would you rate the quality of the services you have\nreceived from this supportive services provider?
# 2  How would you rate the quality of the services you have\nreceived from this supportive services provider?
# 3   How would you rate the quality of the services you have received from this supportive services provider?
# 4                        HOW WOULD YOU RATE THE QUALITY OF SERVICES YOU HAVE RECEIVED FROM THIS SSVF AGENCY?
#
#   normalized_dlp_label  normalized_label_counts  not_normalized_label_counts
# 0                   Q1                        9                            9
# 1                   Q1                        9                            9
# 2                   Q1                        9                            9
# 3                   Q1                        9                            9
# 4                   Q1                        9                            9

# %%
#I want to know which Q labels with a source_type of "table" don't have a Q label with a source type of "pdf" or
#a source type of "data dictionary". I especially want to know this for observations where percent_nonnull is
#not na and is > 0.

#For this, I'll check if every given_q_label value with a source type of "pdf" or a source
#type of "data dictionary" appears in any given_q_label with a source type of "table."

(
    counted_dlp_qs
    [counted_dlp_qs["source_type"] == "table"]
    ["given_q_label"] #for labels with the source type of table ...
    .isin( 
        counted_dlp_qs
        [(counted_dlp_qs["source_type"] == "pdf")
        |
        (counted_dlp_qs["source_type"] == "data dictionary")]
        ["given_q_label"]) #see if any value from a pdf or the data dictionary appears within them.
).value_counts()

#The false values are how many "pdf" and "data dictionary" values
#don't exist in the "table" column
# Out:
# given_q_label
# True     120
# False    108
# Name: count, dtype: int64

# %%
#Let's identify those false values:

filter_for_table_labels_defined_by_pdf_or_dict = (
    counted_dlp_qs
    [counted_dlp_qs["source_type"] == "table"]
    ["given_q_label"]
    .isin(
        counted_dlp_qs
        [(counted_dlp_qs["source_type"] == "pdf")
        |
        (counted_dlp_qs["source_type"] == "data dictionary")]
        ["given_q_label"])
)
filter_for_table_labels_defined_by_pdf_or_dict.head()
# Out:
# 5     True
# 6     True
# 7     True
# 14    True
# 15    True
# Name: given_q_label, dtype: bool

# %%
table_labels_defined_by_pdf_or_dict = (
    counted_dlp_qs[filter_for_table_labels_defined_by_pdf_or_dict]
)
# Out:
# /var/folders/cl/myc9mwnx15nbmsd02f_ct27h0000gn/T/ipykernel_14702/1604140302.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   counted_dlp_qs[filter_for_table_labels_defined_by_pdf_or_dict]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[22], line 2
#       1 table_labels_defined_by_pdf_or_dict = (
# ----> 2     counted_dlp_qs[filter_for_table_labels_defined_by_pdf_or_dict]
#       3 )
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/pandas/core/frame.py:3752, in DataFrame.__getitem__(self, key)
#    3750 # Do we have a (boolean) 1d indexer?
#    3751 if com.is_bool_indexer(key):
# -> 3752     return self._getitem_bool_array(key)
#    3754 # We are left with two options: a single key, and a collection of keys,
#    3755 # We interpret tuples as collections only for non-MultiIndex
#    3756 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/pandas/core/frame.py:3805, in DataFrame._getitem_bool_array(self, key)
#    3799     raise ValueError(
#    3800         f"Item wrong length {len(key)} instead of {len(self.index)}."
#    3801     )
#    3803 # check_bool_indexer will throw exception if Series key cannot
#    3804 # be reindexed to match DataFrame rows
# -> 3805 key = check_bool_indexer(self.index, key)
#    3807 if key.all():
#    3808     return self.copy(deep=None)
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/pandas/core/indexing.py:2506, in check_bool_indexer(index, key)
#    2504 indexer = result.index.get_indexer_for(index)
#    2505 if -1 in indexer:
# -> 2506     raise IndexingError(
#    2507         "Unalignable boolean Series provided as "
#    2508         "indexer (index of the boolean Series and of "
#    2509         "the indexed object do not match)."
#    2510     )
#    2512 result = result.take(indexer)
#    2514 # fall through for boolean
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
#Let's try to fix this ... Looks like the indexes don't match.

# %%
index_of_filter_for_table_labels_defined_by_pdf_or_dict = (
    filter_for_table_labels_defined_by_pdf_or_dict
    .index) #create an index for the filter

(
    counted_dlp_qs.loc[ #Within the main table,
        index_of_filter_for_table_labels_defined_by_pdf_or_dict, :] #locate rows with the index of the filter.
    [filter_for_table_labels_defined_by_pdf_or_dict] #Use that filter, as well.
).head()
# Out:
#    given_q_label given_q_text source_type    num  percent_nonnull  \
# 5             Q1          NaN       table  16-17           100.00
# 6             Q1          NaN       table  18-20           100.00
# 7             Q1          NaN       table  21-22           100.00
# 14            Q7          NaN       table  16-17             0.00
# 15            Q7          NaN       table  18-20            84.39
#
#     consistent/inconsistent  dlp_std_q  dlp_id_for_std_q  \
# 5                       NaN        NaN               NaN
# 6                       NaN        NaN               NaN
# 7                       NaN        NaN               NaN
# 14                      NaN        NaN               NaN
# 15                      NaN        NaN               NaN
#
#     dlp_qid_all_qs (index) notes given_q_text normalized_dlp_label  \
# 5                      NaN   NaN          NaN                   Q1
# 6                      NaN   NaN          NaN                   Q1
# 7                      NaN   NaN          NaN                   Q1
# 14                     NaN   NaN          NaN                   Q7
# 15                     NaN   NaN          NaN                   Q7
#
#     normalized_label_counts  not_normalized_label_counts
# 5                         9                            9
# 6                         9                            9
# 7                         9                            9
# 14                        9                            9
# 15                        9                            9

# %%
#I actually need the reverse because I need the True values
#to be the ones that don't include a source_type of "pdf"
#or "data dictionary." 

#Let's recreate the index with a ~ and use a ~
#in the final filter to get the reverse:

# %%
reversed_filter_for_table_labels_defined_by_pdf_or_dict = ~filter_for_table_labels_defined_by_pdf_or_dict

# %%
reversed_index_of_filter_for_table_labels_defined_by_pdf_or_dict = (
    reversed_filter_for_table_labels_defined_by_pdf_or_dict
    .index
) #create an index for the filter

cols_without_definitions_not_normalized = ( #*#THIS IS THE MAIN TABLE
    counted_dlp_qs.loc[ #Again, within the main table,
        reversed_index_of_filter_for_table_labels_defined_by_pdf_or_dict, :] #locate rows with the index of the filter.
    [reversed_filter_for_table_labels_defined_by_pdf_or_dict] #Reverse the main filter, as well.
)

# %%
( #labels without a definition that have a "Q"
    cols_without_definitions_not_normalized
    [cols_without_definitions_not_normalized
    ["given_q_label"]
    .str.contains("Q")]
)
# Out:
#      given_q_label given_q_text source_type    num  percent_nonnull  \
# 261  Q8.4-c_6_TEXT          NaN       table  16-17             8.17
# 263            Q17          NaN       table  16-17            86.36
# 264            Q18          NaN       table  16-17            37.43
# 270       UNIQUEID          NaN       table  21-22             0.00
# 272            Q12          NaN       table  21-22             4.78
# 274         Q3_3G2          NaN       table  21-22           100.00
# 275         Q1 Num          NaN       table  21-22           100.00
# 285       Q8.4-c_5          NaN       table  16-17            27.45
# 288       Q8.4-c_6          NaN       table  16-17            16.52
# 289       Q8.3-c_1          NaN       table  16-17            38.95
# 290       Q8.4-c_4          NaN       table  16-17            22.24
# 291            QIS          NaN       table  16-17            98.29
# 297          Q_URL          NaN       table  16-17             0.00
# 298            Q35          NaN       table  16-17            95.95
# 299           QIVA          NaN       table  16-17            99.62
# 302        Q8 into          NaN       table  16-17            40.80
# 303        Q8.1-1a          NaN       table  16-17            94.02
# 304        Q8.1-1b          NaN       table  16-17            93.06
# 305      Q8.1-1c_1          NaN       table  16-17            80.49
# 306        Q8.2-2a          NaN       table  16-17            92.98
# 307        Q8.2-2b          NaN       table  16-17            92.17
# 310       Q8.3-a_1          NaN       table  16-17            85.29
# 328      Q8.2-2c_1          NaN       table  16-17            51.08
# 329       Q8.3-a_2          NaN       table  16-17            83.71
# 330       Q8.4-c_3          NaN       table  16-17            52.31
# 331       Q8.4-b_1          NaN       table  16-17            84.47
# 332       Q8.4-a_1          NaN       table  16-17            87.17
# 333       Q8.4-a_2          NaN       table  16-17            83.85
# 334       Q8.4-a_3          NaN       table  16-17            84.71
# 335       Q8.4-a_4          NaN       table  16-17            81.48
# 336       Q8.4-a_5          NaN       table  16-17            81.56
# 337       Q8.4-a_6          NaN       table  16-17            58.94
# 338  Q8.4-a_6_TEXT          NaN       table  16-17            14.27
# 339       Q8.4-b_2          NaN       table  16-17            79.39
# 340       Q8.3-c_7          NaN       table  16-17            12.51
# 341       Q8.4-b_3          NaN       table  16-17            81.36
# 342       Q8.4-b_4          NaN       table  16-17            75.94
# 343       Q8.4-b_5          NaN       table  16-17            76.84
# 344       Q8.4-b_6          NaN       table  16-17            58.26
# 345  Q8.4-b_6_TEXT          NaN       table  16-17            10.26
# 346       Q8.4-c_1          NaN       table  16-17            66.23
# 347       Q8.4-c_2          NaN       table  16-17            39.66
# 348       Q8.3-c_8          NaN       table  16-17            52.23
# 349       Q8.3-c_6          NaN       table  16-17            20.73
# 350       Q8.3-a_3          NaN       table  16-17            83.18
# 351       Q8.3-b_3          NaN       table  16-17            77.80
# 352       Q8.3-a_4          NaN       table  16-17            83.10
# 353       Q8.3-a_5          NaN       table  16-17            84.68
# 354       Q8.3-a_6          NaN       table  16-17            80.82
# 355       Q8.3-a_7          NaN       table  16-17            78.45
# 356       Q8.3-a_8          NaN       table  16-17            83.32
# 357       Q8.3-b_1          NaN       table  16-17            77.96
# 358       Q8.3-b_2          NaN       table  16-17            77.68
# 359       Q8.3-b_4          NaN       table  16-17            77.43
# 360       Q8.3-c_5          NaN       table  16-17            43.10
# 361       Q8.3-b_5          NaN       table  16-17            78.73
# 362       Q8.3-b_6          NaN       table  16-17            74.27
# 363       Q8.3-b_7          NaN       table  16-17            71.62
# 364       Q8.3-b_8          NaN       table  16-17            79.56
# 365       Q8.3-c_2          NaN       table  16-17            38.39
# 366       Q8.3-c_3          NaN       table  16-17            38.36
# 367       Q8.3-c_4          NaN       table  16-17            33.68
#
#      consistent/inconsistent  dlp_std_q  dlp_id_for_std_q  \
# 261                      NaN        NaN               NaN
# 263                      NaN        NaN               NaN
# 264                      NaN        NaN               NaN
# 270                      NaN        NaN               NaN
# 272                      NaN        NaN               NaN
# 274                      NaN        NaN               NaN
# 275                      NaN        NaN               NaN
# 285                      NaN        NaN               NaN
# 288                      NaN        NaN               NaN
# 289                      NaN        NaN               NaN
# 290                      NaN        NaN               NaN
# 291                      NaN        NaN               NaN
# 297                      NaN        NaN               NaN
# 298                      NaN        NaN               NaN
# 299                      NaN        NaN               NaN
# 302                      NaN        NaN               NaN
# 303                      NaN        NaN               NaN
# 304                      NaN        NaN               NaN
# 305                      NaN        NaN               NaN
# 306                      NaN        NaN               NaN
# 307                      NaN        NaN               NaN
# 310                      NaN        NaN               NaN
# 328                      NaN        NaN               NaN
# 329                      NaN        NaN               NaN
# 330                      NaN        NaN               NaN
# 331                      NaN        NaN               NaN
# 332                      NaN        NaN               NaN
# 333                      NaN        NaN               NaN
# 334                      NaN        NaN               NaN
# 335                      NaN        NaN               NaN
# 336                      NaN        NaN               NaN
# 337                      NaN        NaN               NaN
# 338                      NaN        NaN               NaN
# 339                      NaN        NaN               NaN
# 340                      NaN        NaN               NaN
# 341                      NaN        NaN               NaN
# 342                      NaN        NaN               NaN
# 343                      NaN        NaN               NaN
# 344                      NaN        NaN               NaN
# 345                      NaN        NaN               NaN
# 346                      NaN        NaN               NaN
# 347                      NaN        NaN               NaN
# 348                      NaN        NaN               NaN
# 349                      NaN        NaN               NaN
# 350                      NaN        NaN               NaN
# 351                      NaN        NaN               NaN
# 352                      NaN        NaN               NaN
# 353                      NaN        NaN               NaN
# 354                      NaN        NaN               NaN
# 355                      NaN        NaN               NaN
# 356                      NaN        NaN               NaN
# 357                      NaN        NaN               NaN
# 358                      NaN        NaN               NaN
# 359                      NaN        NaN               NaN
# 360                      NaN        NaN               NaN
# 361                      NaN        NaN               NaN
# 362                      NaN        NaN               NaN
# 363                      NaN        NaN               NaN
# 364                      NaN        NaN               NaN
# 365                      NaN        NaN               NaN
# 366                      NaN        NaN               NaN
# 367                      NaN        NaN               NaN
#
#      dlp_qid_all_qs (index) notes given_q_text normalized_dlp_label  \
# 261                     NaN   NaN          NaN        Q8.4-C_6_TEXT
# 263                     NaN   NaN          NaN                  Q17
# 264                     NaN   NaN          NaN                  Q18
# 270                     NaN   NaN          NaN             UNIQUEID
# 272                     NaN   NaN          NaN                  Q12
# 274                     NaN   NaN          NaN               Q3_3G2
# 275                     NaN   NaN          NaN               Q1 NUM
# 285                     NaN   NaN          NaN             Q8.4-C_5
# 288                     NaN   NaN          NaN             Q8.4-C_6
# 289                     NaN   NaN          NaN             Q8.3-C_1
# 290                     NaN   NaN          NaN             Q8.4-C_4
# 291                     NaN   NaN          NaN                  QIS
# 297                     NaN   NaN          NaN                Q_URL
# 298                     NaN   NaN          NaN                  Q35
# 299                     NaN   NaN          NaN                 QIVA
# 302                     NaN   NaN          NaN              Q8 INTO
# 303                     NaN   NaN          NaN              Q8.1-1A
# 304                     NaN   NaN          NaN              Q8.1-1B
# 305                     NaN   NaN          NaN            Q8.1-1C_1
# 306                     NaN   NaN          NaN              Q8.2-2A
# 307                     NaN   NaN          NaN              Q8.2-2B
# 310                     NaN   NaN          NaN             Q8.3-A_1
# 328                     NaN   NaN          NaN            Q8.2-2C_1
# 329                     NaN   NaN          NaN             Q8.3-A_2
# 330                     NaN   NaN          NaN             Q8.4-C_3
# 331                     NaN   NaN          NaN             Q8.4-B_1
# 332                     NaN   NaN          NaN             Q8.4-A_1
# 333                     NaN   NaN          NaN             Q8.4-A_2
# 334                     NaN   NaN          NaN             Q8.4-A_3
# 335                     NaN   NaN          NaN             Q8.4-A_4
# 336                     NaN   NaN          NaN             Q8.4-A_5
# 337                     NaN   NaN          NaN             Q8.4-A_6
# 338                     NaN   NaN          NaN        Q8.4-A_6_TEXT
# 339                     NaN   NaN          NaN             Q8.4-B_2
# 340                     NaN   NaN          NaN             Q8.3-C_7
# 341                     NaN   NaN          NaN             Q8.4-B_3
# 342                     NaN   NaN          NaN             Q8.4-B_4
# 343                     NaN   NaN          NaN             Q8.4-B_5
# 344                     NaN   NaN          NaN             Q8.4-B_6
# 345                     NaN   NaN          NaN        Q8.4-B_6_TEXT
# 346                     NaN   NaN          NaN             Q8.4-C_1
# 347                     NaN   NaN          NaN             Q8.4-C_2
# 348                     NaN   NaN          NaN             Q8.3-C_8
# 349                     NaN   NaN          NaN             Q8.3-C_6
# 350                     NaN   NaN          NaN             Q8.3-A_3
# 351                     NaN   NaN          NaN             Q8.3-B_3
# 352                     NaN   NaN          NaN             Q8.3-A_4
# 353                     NaN   NaN          NaN             Q8.3-A_5
# 354                     NaN   NaN          NaN             Q8.3-A_6
# 355                     NaN   NaN          NaN             Q8.3-A_7
# 356                     NaN   NaN          NaN             Q8.3-A_8
# 357                     NaN   NaN          NaN             Q8.3-B_1
# 358                     NaN   NaN          NaN             Q8.3-B_2
# 359                     NaN   NaN          NaN             Q8.3-B_4
# 360                     NaN   NaN          NaN             Q8.3-C_5
# 361                     NaN   NaN          NaN             Q8.3-B_5
# 362                     NaN   NaN          NaN             Q8.3-B_6
# 363                     NaN   NaN          NaN             Q8.3-B_7
# 364                     NaN   NaN          NaN             Q8.3-B_8
# 365                     NaN   NaN          NaN             Q8.3-C_2
# 366                     NaN   NaN          NaN             Q8.3-C_3
# 367                     NaN   NaN          NaN             Q8.3-C_4
#
#      normalized_label_counts  not_normalized_label_counts
# 261                        1                            1
# 263                        1                            1
# 264                        1                            1
# 270                        1                            1
# 272                        1                            1
# 274                        1                            1
# 275                        1                            1
# 285                        1                            1
# 288                        1                            1
# 289                        1                            1
# 290                        1                            1
# 291                        1                            1
# 297                        1                            1
# 298                        1                            1
# 299                        1                            1
# 302                        1                            1
# 303                        1                            1
# 304                        1                            1
# 305                        1                            1
# 306                        1                            1
# 307                        1                            1
# 310                        1                            1
# 328                        1                            1
# 329                        1                            1
# 330                        1                            1
# 331                        1                            1
# 332                        1                            1
# 333                        1                            1
# 334                        1                            1
# 335                        1                            1
# 336                        1                            1
# 337                        1                            1
# 338                        1                            1
# 339                        1                            1
# 340                        1                            1
# 341                        1                            1
# 342                        1                            1
# 343                        1                            1
# 344                        1                            1
# 345                        1                            1
# 346                        1                            1
# 347                        1                            1
# 348                        1                            1
# 349                        1                            1
# 350                        1                            1
# 351                        1                            1
# 352                        1                            1
# 353                        1                            1
# 354                        1                            1
# 355                        1                            1
# 356                        1                            1
# 357                        1                            1
# 358                        1                            1
# 359                        1                            1
# 360                        1                            1
# 361                        1                            1
# 362                        1                            1
# 363                        1                            1
# 364                        1                            1
# 365                        1                            1
# 366                        1                            1
# 367                        1                            1

# %%
( #creating a csv from the above table
    cols_without_definitions_not_normalized
    [cols_without_definitions_not_normalized
    ["given_q_label"]
    .str.contains("Q")]
    [["given_q_label", "source_type", "num"]] #Let's keep the table simple. What's missing a definition, and where is the source?
    .drop([270]) #"UNIQUEID" isn't a question
    .to_csv("ssvf_question-labels-without-definitions.csv")
)

# %%
( #looking at the labels without "Q" to make sure I'm not missing anything.
    cols_without_definitions_not_normalized
    .loc[lambda df: (
        ~df["given_q_label"]
        .str.contains("Q"))]
)
# Out:
#                                                            given_q_label  \
# 260                                                               REMAIL
# 262                                                                PHONE
# 265                                                           date range
# 266                                                                  PIN
# 267                                                                FNAME
# 268                                                             Negative
# 269                                                             LtCallST
# 271                                                                 Date
# 273                                                                INT99
# 276                                                          HEALTHCARE2
# 277                                                           HEALTHCARE
# 278                                                            HOUSEHOLD
# 279                                                              LtCaseR
# 280                                                            GRANTEEID
# 281                                                              LtCallR
# 282                                                            TotalTime
# 283                                                             CallDurM
# 284                                                             CallDurS
# 286                                                             LtCallDt
# 287                                                                 MODE
# 292  How many people are in the veterans household including the veteran
# 293       Veterans First Name if first name is not provided  please type
# 294                                  Veterans Email Address yourname.com
# 295                               Cell Phone XXX-XXX-XXXX 1-999-999-9999
# 296                                                            UserAgent
# 300                                                     Respondent Email
# 301                                                                  F37
# 308                                                               Region
# 309                                                    Custom Variable 4
# 311                                                       RecipientEmail
# 313                                                          ResponseSet
# 314                                                            IPAddress
# 315                                                            StartDate
# 316                                                              EndDate
# 317                                                    RecipientLastName
# 318                                                   RecipientFirstName
# 319                                                ExternalDataReference
# 320                                                    Custom Variable 3
# 321                                                             Finished
# 322                                                               Status
# 323                                                        va Cell Phone
# 324                                                          Response ID
# 325                                                 Timestamp MM/dd/yyyy
# 326                                                    Custom Variable 1
# 327                                                    Custom Variable 2
# 368                                                                  INT
#
#     given_q_text source_type    num  percent_nonnull  consistent/inconsistent  \
# 260          NaN       table  18-20             0.00                      NaN
# 262          NaN       table  18-20             0.00                      NaN
# 265          NaN       table  16-17           100.00                      NaN
# 266          NaN       table  18-20           100.00                      NaN
# 267          NaN       table  18-20             0.00                      NaN
# 268          NaN       table  16-17            13.69                      NaN
# 269          NaN       table  21-22           100.00                      NaN
# 271          NaN       table  21-22           100.00                      NaN
# 273          NaN       table  21-22             5.56                      NaN
# 276          NaN       table  21-22           100.00                      NaN
# 277          NaN       table  21-22           100.00                      NaN
# 278          NaN       table  21-22           100.00                      NaN
# 279          NaN       table  21-22             5.91                      NaN
# 280          NaN       table  21-22           100.00                      NaN
# 281          NaN       table  21-22             5.93                      NaN
# 282          NaN       table  21-22            93.73                      NaN
# 283          NaN       table  21-22           100.00                      NaN
# 284          NaN       table  21-22           100.00                      NaN
# 286          NaN       table  21-22           100.00                      NaN
# 287          NaN       table  21-22           100.00                      NaN
# 292          NaN       table  16-17             0.00                      NaN
# 293          NaN       table  16-17             0.00                      NaN
# 294          NaN       table  16-17             0.00                      NaN
# 295          NaN       table  16-17             0.00                      NaN
# 296          NaN       table  16-17             0.00                      NaN
# 300          NaN       table  16-17             0.00                      NaN
# 301          NaN       table  16-17             0.00                      NaN
# 308          NaN       table  16-17            81.60                      NaN
# 309          NaN       table  16-17             0.00                      NaN
# 311          NaN       table  16-17             0.00                      NaN
# 313          NaN       table  16-17           100.00                      NaN
# 314          NaN       table  16-17             0.00                      NaN
# 315          NaN       table  16-17            45.84                      NaN
# 316          NaN       table  16-17           100.00                      NaN
# 317          NaN       table  16-17             7.14                      NaN
# 318          NaN       table  16-17             0.00                      NaN
# 319          NaN       table  16-17             0.00                      NaN
# 320          NaN       table  16-17             0.00                      NaN
# 321          NaN       table  16-17            44.52                      NaN
# 322          NaN       table  16-17            44.52                      NaN
# 323          NaN       table  16-17             7.14                      NaN
# 324          NaN       table  16-17             0.00                      NaN
# 325          NaN       table  16-17            53.46                      NaN
# 326          NaN       table  16-17           100.00                      NaN
# 327          NaN       table  16-17           100.00                      NaN
# 368          NaN       table  21-22            94.01                      NaN
#
#      dlp_std_q  dlp_id_for_std_q  dlp_qid_all_qs (index) notes given_q_text  \
# 260        NaN               NaN                     NaN   NaN          NaN
# 262        NaN               NaN                     NaN   NaN          NaN
# 265        NaN               NaN                     NaN   NaN          NaN
# 266        NaN               NaN                     NaN   NaN          NaN
# 267        NaN               NaN                     NaN   NaN          NaN
# 268        NaN               NaN                     NaN   NaN          NaN
# 269        NaN               NaN                     NaN   NaN          NaN
# 271        NaN               NaN                     NaN   NaN          NaN
# 273        NaN               NaN                     NaN   NaN          NaN
# 276        NaN               NaN                     NaN   NaN          NaN
# 277        NaN               NaN                     NaN   NaN          NaN
# 278        NaN               NaN                     NaN   NaN          NaN
# 279        NaN               NaN                     NaN   NaN          NaN
# 280        NaN               NaN                     NaN   NaN          NaN
# 281        NaN               NaN                     NaN   NaN          NaN
# 282        NaN               NaN                     NaN   NaN          NaN
# 283        NaN               NaN                     NaN   NaN          NaN
# 284        NaN               NaN                     NaN   NaN          NaN
# 286        NaN               NaN                     NaN   NaN          NaN
# 287        NaN               NaN                     NaN   NaN          NaN
# 292        NaN               NaN                     NaN   NaN          NaN
# 293        NaN               NaN                     NaN   NaN          NaN
# 294        NaN               NaN                     NaN   NaN          NaN
# 295        NaN               NaN                     NaN   NaN          NaN
# 296        NaN               NaN                     NaN   NaN          NaN
# 300        NaN               NaN                     NaN   NaN          NaN
# 301        NaN               NaN                     NaN   NaN          NaN
# 308        NaN               NaN                     NaN   NaN          NaN
# 309        NaN               NaN                     NaN   NaN          NaN
# 311        NaN               NaN                     NaN   NaN          NaN
# 313        NaN               NaN                     NaN   NaN          NaN
# 314        NaN               NaN                     NaN   NaN          NaN
# 315        NaN               NaN                     NaN   NaN          NaN
# 316        NaN               NaN                     NaN   NaN          NaN
# 317        NaN               NaN                     NaN   NaN          NaN
# 318        NaN               NaN                     NaN   NaN          NaN
# 319        NaN               NaN                     NaN   NaN          NaN
# 320        NaN               NaN                     NaN   NaN          NaN
# 321        NaN               NaN                     NaN   NaN          NaN
# 322        NaN               NaN                     NaN   NaN          NaN
# 323        NaN               NaN                     NaN   NaN          NaN
# 324        NaN               NaN                     NaN   NaN          NaN
# 325        NaN               NaN                     NaN   NaN          NaN
# 326        NaN               NaN                     NaN   NaN          NaN
# 327        NaN               NaN                     NaN   NaN          NaN
# 368        NaN               NaN                     NaN   NaN          NaN
#
#                                                     normalized_dlp_label  \
# 260                                                               REMAIL
# 262                                                                PHONE
# 265                                                           DATE RANGE
# 266                                                                  PIN
# 267                                                                FNAME
# 268                                                             NEGATIVE
# 269                                                             LTCALLST
# 271                                                                 DATE
# 273                                                                INT99
# 276                                                          HEALTHCARE2
# 277                                                           HEALTHCARE
# 278                                                            HOUSEHOLD
# 279                                                              LTCASER
# 280                                                            GRANTEEID
# 281                                                              LTCALLR
# 282                                                            TOTALTIME
# 283                                                             CALLDURM
# 284                                                             CALLDURS
# 286                                                             LTCALLDT
# 287                                                                 MODE
# 292  HOW MANY PEOPLE ARE IN THE VETERANS HOUSEHOLD INCLUDING THE VETERAN
# 293       VETERANS FIRST NAME IF FIRST NAME IS NOT PROVIDED  PLEASE TYPE
# 294                                  VETERANS EMAIL ADDRESS YOURNAME.COM
# 295                               CELL PHONE XXX-XXX-XXXX 1-999-999-9999
# 296                                                            USERAGENT
# 300                                                     RESPONDENT EMAIL
# 301                                                                  F37
# 308                                                               REGION
# 309                                                    CUSTOM VARIABLE 4
# 311                                                       RECIPIENTEMAIL
# 313                                                          RESPONSESET
# 314                                                            IPADDRESS
# 315                                                            STARTDATE
# 316                                                              ENDDATE
# 317                                                    RECIPIENTLASTNAME
# 318                                                   RECIPIENTFIRSTNAME
# 319                                                EXTERNALDATAREFERENCE
# 320                                                    CUSTOM VARIABLE 3
# 321                                                             FINISHED
# 322                                                               STATUS
# 323                                                        VA CELL PHONE
# 324                                                          RESPONSE ID
# 325                                                 TIMESTAMP MM/DD/YYYY
# 326                                                    CUSTOM VARIABLE 1
# 327                                                    CUSTOM VARIABLE 2
# 368                                                                  INT
#
#      normalized_label_counts  not_normalized_label_counts
# 260                        1                            1
# 262                        1                            1
# 265                        1                            1
# 266                        1                            1
# 267                        1                            1
# 268                        1                            1
# 269                        1                            1
# 271                        1                            1
# 273                        1                            1
# 276                        1                            1
# 277                        1                            1
# 278                        1                            1
# 279                        1                            1
# 280                        1                            1
# 281                        1                            1
# 282                        1                            1
# 283                        1                            1
# 284                        1                            1
# 286                        1                            1
# 287                        1                            1
# 292                        1                            1
# 293                        1                            1
# 294                        1                            1
# 295                        1                            1
# 296                        1                            1
# 300                        1                            1
# 301                        1                            1
# 308                        1                            1
# 309                        1                            1
# 311                        1                            1
# 313                        1                            1
# 314                        1                            1
# 315                        1                            1
# 316                        1                            1
# 317                        1                            1
# 318                        1                            1
# 319                        1                            1
# 320                        1                            1
# 321                        1                            1
# 322                        1                            1
# 323                        1                            1
# 324                        1                            1
# 325                        1                            1
# 326                        1                            1
# 327                        1                            1
# 368                        1                            1

# %%
#I should probably check what happens if I normalize the above steps ...

# %%
(
    counted_dlp_qs
    [counted_dlp_qs["source_type"] == "table"]
    ["given_q_label"] #for labels with the source type of table ...
    .str.upper()
    .isin( 
        counted_dlp_qs
        [(counted_dlp_qs["source_type"] == "pdf")
        |
        (counted_dlp_qs["source_type"] == "data dictionary")]
        ["given_q_label"] #see if any value from a pdf or the data dictionary appears within them.
        .str.upper())
).value_counts()
# Out:
# given_q_label
# True     120
# False    108
# Name: count, dtype: int64

# %%
#Whew ... True 120, False 108 — the same as before. No need to go through all of the same steps with uppercasing.

# %%
#*end of looking into questions without a definition

# %%
#Now, I should try the reverse: Check the PDFs and 
#data dictionary for values that aren't included in the observational tables.
#But, you know what — I can do it later. I should report to Jeremy.

# %%
len(df_16_17.melt())
# Out:
# 814625

# %%
len(df_16_17)
# Out:
# 8575
